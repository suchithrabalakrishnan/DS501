# %% [markdown]
# # Case Study 3 : Textual analysis of movie reviews
#
# ** Due Date: November 17, 2016 5:59PM**
#
# *------------

# %% [markdown]
# <img src="http://www.conversational-technologies.com/nldemos/nlWordle.GIF">

# %% [markdown]
# **TEAM Members:** Please EDIT this cell and add the names of all the team members in your team
#
#     Guanxiong Liu
#     Jiankun Bi
#     Naveen Pothayath
#     Suchithra Balakrishnan
#     Abhishek Easwaran

# %% [markdown]
# **Desired outcome of the case study.**
# * In this case study we will look at movie reviews from the v2.0 polarity dataset comes from
# the http://www.cs.cornell.edu/people/pabo/movie-review-data.
#     * It contains written reviews of movies divided into positive and negative reviews.
# * As in Case Study 2 idea is to *analyze* the data set, make *conjectures*, support or refute those conjectures with *data*, and *tell a story* about the data!
#
# **Required Readings:**
# * This case study will be based upon the scikit-learn Python library
# * We will build upon the turtorial "Working With Text Data" which can be found at http://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html
#
# **Case study assumptions:**
# * You have access to a python installation
#
# **Required Python libraries:**
# * Numpy (www.numpy.org) (should already be installed from Case Study 2)
# * Matplotlib (matplotlib.org) (should already be installed from Case Study 2)
# * Scikit-learn (scikit-learn.org) (avaiable from Enthought Canopy)
# * You are also welcome to use the Python Natural Language Processing Toolkit (www.nltk.org) (though it is not required).
#
# ** NOTE **
# * Please don't forget to save the notebook frequently when working in IPython Notebook, otherwise the changes you made can be lost.
#
# *----------------------

# %% [markdown]
# ## Problem 1 (20 points): Complete Exercise 2: Sentiment Analysis on movie reviews from http://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html

# %% [markdown]
# * Assuming that you have downloaded the scikit-learn source code:
#     * The data cane be downloaded using doc/tutorial/text_analytics/data/movie_reviews/fetch_data.py
#     * A skeleton for the solution can be found in doc/tutorial/text_analytics/skeletons/exercise_02_sentiment.py
#     * A completed solution can be found in doc/tutorial/text_analytics/solutions/exercise_02_sentiment.py
# * **It is ok to use the solution provided in the scikit-learn distribution as a starting place for your work.**
#
# ### Modify the solution to Exercise 2 so that it can run in this iPython notebook
# * This will likely involved moving around data files and/or small modifications to the script.

# %%
# import libs
import sys
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import load_files
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# read in data
dataset = load_files('./text_analytics/data/movie_reviews/txt_sentoken/', shuffle=False)
print("n_samples: %d" % len(dataset.data))
# Out:
# n_samples: 2000

# %%
# split into training and test data sets
docs_train, docs_test, y_train, y_test = train_test_split(dataset.data, dataset.target, 
                                                          test_size=0.25, random_state=None)

# %%
# building pipeline which is used to process the data in order
pipeline = Pipeline([
        ('vect', TfidfVectorizer(min_df=3, max_df=0.95)), # vectorization
        ('clf', LinearSVC(C=1000)), # linear support vector classifier
    ])

# %%
# set up parameters for voctorization process and use grid_search to fit the training data
parameters = {
        'vect__ngram_range': [(1, 1), (1, 2)],
    }
grid_search = GridSearchCV(pipeline, parameters, n_jobs=-1)
grid_search.fit(docs_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Pipeline(steps=[('vect', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.95, max_features=None, min_df=3,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#  ...ax_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0))]),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'vect__ngram_range': [(1, 1), (1, 2)]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
# print out model score
n_candidates = len(grid_search.cv_results_['params'])
for i in range(n_candidates):
    print(i, 'params - %s; mean - %0.2f; std - %0.2f'
             % (grid_search.cv_results_['params'][i],
                grid_search.cv_results_['mean_test_score'][i],
                grid_search.cv_results_['std_test_score'][i]))
# Out:
# 0 params - {'vect__ngram_range': (1, 1)}; mean - 0.82; std - 0.02
# 1 params - {'vect__ngram_range': (1, 2)}; mean - 0.83; std - 0.01

# %%
# predict the test data set and print out the result with best cross validation model
y_predicted = grid_search.predict(docs_test)
print(metrics.classification_report(y_test, y_predicted, 
                                    target_names=dataset.target_names)) # classification result
cm = metrics.confusion_matrix(y_test, y_predicted) # confusion matrix
print(cm)
# Out:
#              precision    recall  f1-score   support
#
#         neg       0.90      0.87      0.88       247
#         pos       0.88      0.91      0.89       253
#
# avg / total       0.89      0.89      0.89       500
#
# [[215  32]
#  [ 24 229]]

# %% [markdown]
# ## Problem 2 (20 points): Explore the scikit-learn TfidVectorizer class
#
# **Read the documentation for the TfidVectorizer class at http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html.**
# * Define the term frequency–inverse document frequency (TF-IDF) statistic (http://en.wikipedia.org/wiki/Tf%E2%80%93idf will likely help).
# * Run the TfidVectorizer class on the training data above (docs_train).
# * Explore the min_df and max_df parameters of TfidVectorizer.  What do they mean? How do they change the features you get?
# * Explore the ngram_range parameter of TfidVectorizer.  What does it mean? How does it change the features you get? (Note, large values  of ngram_range may take a long time to run!)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
for i in np.arange(0.05, 0.3, 0.05):
    vector = TfidfVectorizer(min_df=i, max_df=0.9)
    matrix = vector.fit_transform(docs_train)
    plt.plot(i,matrix.shape[1],'bs')

plt.xlabel('Value of min_df')
plt.ylabel('Number of features')

# %%
for i in np.arange(0.95, 0.7, -0.05):
    vector = TfidfVectorizer(min_df=0.1, max_df=i)
    matrix = vector.fit_transform(docs_train)
    plt.plot(i,matrix.shape[1],'bs')

plt.xlabel('Value of max_df')
plt.ylabel('Number of features')

# %%
ngram_candidate = range(1,6)
for ngram in ngram_candidate:
    vector = TfidfVectorizer(min_df=0.1, max_df=0.9, ngram_range=(1,ngram))
    matrix = vector.fit_transform(docs_train)
    plt.plot(ngram,matrix.shape[1],'bs')

plt.xlabel('Upper bound of ngram')
plt.ylabel('Number of features')

# %% [markdown]
# *------------------------
#
# ## Problem 3 (20 points): Machine learning algorithms

# %% [markdown]
# * Based upon Problem 2 pick some parameters for TfidfVectorizer
#     * "fit" your TfidfVectorizer using docs_train
#     * Compute "Xtrain", a Tf-idf-weighted document-term matrix using the transform function on docs_train
#     * Compute "Xtest", a Tf-idf-weighted document-term matrix using the transform function on docs_test
#     * Note, be sure to use the same Tf-idf-weighted class (**"fit" using docs_train**) to transform **both** docs_test and docs_train
# * Examine two classifiers provided by scikit-learn
#     * LinearSVC
#     * KNeighborsClassifier
#     * Try a number of different parameter settings for each and judge your performance using a confusion matrix (see Problem 1 for an example).
# * Does one classifier, or one set of parameters work better?
#     * Why do you think it might be working better?
# * For a particular choice of parameters and classifier, look at 2 examples where the prediction was incorrect.
#     * Can you conjecture on why the classifier made a mistake for this prediction?

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.decomposition import TruncatedSVD
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# prepare the Xtrain and Xtest
vector = TfidfVectorizer(min_df=3, max_df=0.95, ngram_range=(1,2))
vector.fit(docs_train)

Xtrain = vector.transform(docs_train)
Xtest  = vector.transform(docs_test)

# %%
# examine LinearSVC
svc_C = [1000, 100, 10, 1, 0.1, 0.01]
precision = []
recall = []

for param in svc_C:
    svc = LinearSVC(C=param)
    svc.fit(Xtrain, y_train)
    y_predicted = svc.predict(Xtest)
    
    cm = metrics.confusion_matrix(y_test, y_predicted) # confusion matrix
    precision.append(cm[1,1] / (1.0 * (cm[1,1] + cm[0,1])))
    recall.append(cm[1,1] / (1.0 * (cm[1,1] + cm[1,0])))
    
plt.semilogx(svc_C, precision, '-bs', label='Precision')
plt.semilogx(svc_C, recall, '-ro', label='Recall')
plt.xlabel('Penalty Value')
plt.ylabel('Percentage')
plt.legend(loc='best')

# %%
# examine LinearSVC
KNN_n_neighbors = [2, 4, 8, 16, 32, 64, 128]
precision = []
recall = []

for param in KNN_n_neighbors:
    KNN = KNeighborsClassifier(n_neighbors=param)
    KNN.fit(Xtrain, y_train)
    y_predicted = KNN.predict(Xtest)
    
    cm = metrics.confusion_matrix(y_test, y_predicted) # confusion matrix
    precision.append(cm[1,1] / (1.0 * (cm[1,1] + cm[0,1])))
    recall.append(cm[1,1] / (1.0 * (cm[1,1] + cm[1,0])))
    
plt.semilogx(KNN_n_neighbors, precision, '-bs', label='Precision', basex=2)
plt.semilogx(KNN_n_neighbors, recall, '-ro', label='Recall', basex=2)
plt.xlabel('Number of neighbors')
plt.ylabel('Percentage')
plt.legend(loc='best')

# %%
# LinearSVC
print ('======= Start Evaluation of LinearSVC =======')
pipeline = Pipeline([
        ('vect', TfidfVectorizer()), # vectorization
        ('clf', LinearSVC()), # linear support vector classifier
    ])

parameters = {
        'vect__ngram_range': [(1, 2), (1, 3)],
        'vect__min_df': [2, 3, 4],
        'vect__max_df': [0.98, 0.95, 0.92],
        'clf__C': [1000, 800, 600],
    }

grid_search = GridSearchCV(pipeline, parameters, n_jobs=-1)
grid_search.fit(docs_train, y_train)

n_candidates = len(grid_search.cv_results_['params'])
for i in range(n_candidates):
    print(i, 'params - %s; mean - %0.2f; std - %0.2f'
             % (grid_search.cv_results_['params'][i],
                grid_search.cv_results_['mean_test_score'][i],
                grid_search.cv_results_['std_test_score'][i]))

y_predicted = grid_search.predict(docs_test)
print(metrics.classification_report(y_test, y_predicted, 
                                    target_names=dataset.target_names)) # classification result
cm = metrics.confusion_matrix(y_test, y_predicted) # confusion matrix
print(cm)
# Out:
# ======= Start Evaluation of LinearSVC =======
# 0 params - {'vect__ngram_range': (1, 2), 'clf__C': 1000, 'vect__min_df': 2, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 1 params - {'vect__ngram_range': (1, 3), 'clf__C': 1000, 'vect__min_df': 2, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 2 params - {'vect__ngram_range': (1, 2), 'clf__C': 1000, 'vect__min_df': 3, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 3 params - {'vect__ngram_range': (1, 3), 'clf__C': 1000, 'vect__min_df': 3, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 4 params - {'vect__ngram_range': (1, 2), 'clf__C': 1000, 'vect__min_df': 4, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 5 params - {'vect__ngram_range': (1, 3), 'clf__C': 1000, 'vect__min_df': 4, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 6 params - {'vect__ngram_range': (1, 2), 'clf__C': 1000, 'vect__min_df': 2, 'vect__max_df': 0.95}; mean - 0.84; std - 0.01
# 7 params - {'vect__ngram_range': (1, 3), 'clf__C': 1000, 'vect__min_df': 2, 'vect__max_df': 0.95}; mean - 0.84; std - 0.01
# 8 params - {'vect__ngram_range': (1, 2), 'clf__C': 1000, 'vect__min_df': 3, 'vect__max_df': 0.95}; mean - 0.84; std - 0.00
# 9 params - {'vect__ngram_range': (1, 3), 'clf__C': 1000, 'vect__min_df': 3, 'vect__max_df': 0.95}; mean - 0.84; std - 0.01
# 10 params - {'vect__ngram_range': (1, 2), 'clf__C': 1000, 'vect__min_df': 4, 'vect__max_df': 0.95}; mean - 0.84; std - 0.01
# 11 params - {'vect__ngram_range': (1, 3), 'clf__C': 1000, 'vect__min_df': 4, 'vect__max_df': 0.95}; mean - 0.84; std - 0.01
# 12 params - {'vect__ngram_range': (1, 2), 'clf__C': 1000, 'vect__min_df': 2, 'vect__max_df': 0.92}; mean - 0.84; std - 0.00
# 13 params - {'vect__ngram_range': (1, 3), 'clf__C': 1000, 'vect__min_df': 2, 'vect__max_df': 0.92}; mean - 0.84; std - 0.01
# 14 params - {'vect__ngram_range': (1, 2), 'clf__C': 1000, 'vect__min_df': 3, 'vect__max_df': 0.92}; mean - 0.84; std - 0.00
# 15 params - {'vect__ngram_range': (1, 3), 'clf__C': 1000, 'vect__min_df': 3, 'vect__max_df': 0.92}; mean - 0.84; std - 0.01
# 16 params - {'vect__ngram_range': (1, 2), 'clf__C': 1000, 'vect__min_df': 4, 'vect__max_df': 0.92}; mean - 0.85; std - 0.01
# 17 params - {'vect__ngram_range': (1, 3), 'clf__C': 1000, 'vect__min_df': 4, 'vect__max_df': 0.92}; mean - 0.85; std - 0.01
# 18 params - {'vect__ngram_range': (1, 2), 'clf__C': 800, 'vect__min_df': 2, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 19 params - {'vect__ngram_range': (1, 3), 'clf__C': 800, 'vect__min_df': 2, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 20 params - {'vect__ngram_range': (1, 2), 'clf__C': 800, 'vect__min_df': 3, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 21 params - {'vect__ngram_range': (1, 3), 'clf__C': 800, 'vect__min_df': 3, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 22 params - {'vect__ngram_range': (1, 2), 'clf__C': 800, 'vect__min_df': 4, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 23 params - {'vect__ngram_range': (1, 3), 'clf__C': 800, 'vect__min_df': 4, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 24 params - {'vect__ngram_range': (1, 2), 'clf__C': 800, 'vect__min_df': 2, 'vect__max_df': 0.95}; mean - 0.84; std - 0.01
# 25 params - {'vect__ngram_range': (1, 3), 'clf__C': 800, 'vect__min_df': 2, 'vect__max_df': 0.95}; mean - 0.84; std - 0.01
# 26 params - {'vect__ngram_range': (1, 2), 'clf__C': 800, 'vect__min_df': 3, 'vect__max_df': 0.95}; mean - 0.84; std - 0.00
# 27 params - {'vect__ngram_range': (1, 3), 'clf__C': 800, 'vect__min_df': 3, 'vect__max_df': 0.95}; mean - 0.84; std - 0.01
# 28 params - {'vect__ngram_range': (1, 2), 'clf__C': 800, 'vect__min_df': 4, 'vect__max_df': 0.95}; mean - 0.84; std - 0.01
# 29 params - {'vect__ngram_range': (1, 3), 'clf__C': 800, 'vect__min_df': 4, 'vect__max_df': 0.95}; mean - 0.84; std - 0.01
# 30 params - {'vect__ngram_range': (1, 2), 'clf__C': 800, 'vect__min_df': 2, 'vect__max_df': 0.92}; mean - 0.84; std - 0.00
# 31 params - {'vect__ngram_range': (1, 3), 'clf__C': 800, 'vect__min_df': 2, 'vect__max_df': 0.92}; mean - 0.84; std - 0.01
# 32 params - {'vect__ngram_range': (1, 2), 'clf__C': 800, 'vect__min_df': 3, 'vect__max_df': 0.92}; mean - 0.84; std - 0.00
# 33 params - {'vect__ngram_range': (1, 3), 'clf__C': 800, 'vect__min_df': 3, 'vect__max_df': 0.92}; mean - 0.84; std - 0.01
# 34 params - {'vect__ngram_range': (1, 2), 'clf__C': 800, 'vect__min_df': 4, 'vect__max_df': 0.92}; mean - 0.85; std - 0.01
# 35 params - {'vect__ngram_range': (1, 3), 'clf__C': 800, 'vect__min_df': 4, 'vect__max_df': 0.92}; mean - 0.85; std - 0.01
# 36 params - {'vect__ngram_range': (1, 2), 'clf__C': 600, 'vect__min_df': 2, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 37 params - {'vect__ngram_range': (1, 3), 'clf__C': 600, 'vect__min_df': 2, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 38 params - {'vect__ngram_range': (1, 2), 'clf__C': 600, 'vect__min_df': 3, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 39 params - {'vect__ngram_range': (1, 3), 'clf__C': 600, 'vect__min_df': 3, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 40 params - {'vect__ngram_range': (1, 2), 'clf__C': 600, 'vect__min_df': 4, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 41 params - {'vect__ngram_range': (1, 3), 'clf__C': 600, 'vect__min_df': 4, 'vect__max_df': 0.98}; mean - 0.84; std - 0.01
# 42 params - {'vect__ngram_range': (1, 2), 'clf__C': 600, 'vect__min_df': 2, 'vect__max_df': 0.95}; mean - 0.84; std - 0.01
# 43 params - {'vect__ngram_range': (1, 3), 'clf__C': 600, 'vect__min_df': 2, 'vect__max_df': 0.95}; mean - 0.84; std - 0.01
# 44 params - {'vect__ngram_range': (1, 2), 'clf__C': 600, 'vect__min_df': 3, 'vect__max_df': 0.95}; mean - 0.84; std - 0.00
# 45 params - {'vect__ngram_range': (1, 3), 'clf__C': 600, 'vect__min_df': 3, 'vect__max_df': 0.95}; mean - 0.84; std - 0.01
# 46 params - {'vect__ngram_range': (1, 2), 'clf__C': 600, 'vect__min_df': 4, 'vect__max_df': 0.95}; mean - 0.84; std - 0.01
# 47 params - {'vect__ngram_range': (1, 3), 'clf__C': 600, 'vect__min_df': 4, 'vect__max_df': 0.95}; mean - 0.84; std - 0.01
# 48 params - {'vect__ngram_range': (1, 2), 'clf__C': 600, 'vect__min_df': 2, 'vect__max_df': 0.92}; mean - 0.84; std - 0.00
# 49 params - {'vect__ngram_range': (1, 3), 'clf__C': 600, 'vect__min_df': 2, 'vect__max_df': 0.92}; mean - 0.84; std - 0.01
# 50 params - {'vect__ngram_range': (1, 2), 'clf__C': 600, 'vect__min_df': 3, 'vect__max_df': 0.92}; mean - 0.84; std - 0.00
# 51 params - {'vect__ngram_range': (1, 3), 'clf__C': 600, 'vect__min_df': 3, 'vect__max_df': 0.92}; mean - 0.84; std - 0.01
# 52 params - {'vect__ngram_range': (1, 2), 'clf__C': 600, 'vect__min_df': 4, 'vect__max_df': 0.92}; mean - 0.85; std - 0.01
# 53 params - {'vect__ngram_range': (1, 3), 'clf__C': 600, 'vect__min_df': 4, 'vect__max_df': 0.92}; mean - 0.85; std - 0.01
#              precision    recall  f1-score   support
#
#         neg       0.87      0.85      0.86       252
#         pos       0.85      0.87      0.86       248
#
# avg / total       0.86      0.86      0.86       500
#
# [[215  37]
#  [ 33 215]]

# %%
# K nearst neighbor
print ('======= Start Evaluation of KNN =======')
pipeline = Pipeline([
        ('vect', TfidfVectorizer()), # vectorization
        ('clf', KNeighborsClassifier()), # KNN classifier
    ])

parameters = {
        'vect__ngram_range': [(1, 2), (1, 3)],
        'vect__min_df': [2, 3, 4],
        'vect__max_df': [0.98, 0.95, 0.92],
        'clf__n_neighbors': [16, 32, 64, 128],
    }

grid_search = GridSearchCV(pipeline, parameters, n_jobs=-1)
grid_search.fit(docs_train, y_train)

n_candidates = len(grid_search.cv_results_['params'])
for i in range(n_candidates):
    print(i, 'params - %s; mean - %0.2f; std - %0.2f'
             % (grid_search.cv_results_['params'][i],
                grid_search.cv_results_['mean_test_score'][i],
                grid_search.cv_results_['std_test_score'][i]))

y_predicted = grid_search.predict(docs_test)
print(metrics.classification_report(y_test, y_predicted, 
                                    target_names=dataset.target_names)) # classification result
cm = metrics.confusion_matrix(y_test, y_predicted) # confusion matrix
print(cm)
# Out:
# ======= Start Evaluation of KNN =======
# 0 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 2, 'clf__n_neighbors': 16}; mean - 0.66; std - 0.02
# 1 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 2, 'clf__n_neighbors': 16}; mean - 0.67; std - 0.01
# 2 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 3, 'clf__n_neighbors': 16}; mean - 0.67; std - 0.02
# 3 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 3, 'clf__n_neighbors': 16}; mean - 0.67; std - 0.02
# 4 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 4, 'clf__n_neighbors': 16}; mean - 0.67; std - 0.02
# 5 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 4, 'clf__n_neighbors': 16}; mean - 0.67; std - 0.01
# 6 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 2, 'clf__n_neighbors': 16}; mean - 0.68; std - 0.01
# 7 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 2, 'clf__n_neighbors': 16}; mean - 0.68; std - 0.01
# 8 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 3, 'clf__n_neighbors': 16}; mean - 0.69; std - 0.02
# 9 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 3, 'clf__n_neighbors': 16}; mean - 0.69; std - 0.01
# 10 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 4, 'clf__n_neighbors': 16}; mean - 0.69; std - 0.01
# 11 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 4, 'clf__n_neighbors': 16}; mean - 0.69; std - 0.01
# 12 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 2, 'clf__n_neighbors': 16}; mean - 0.68; std - 0.02
# 13 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 2, 'clf__n_neighbors': 16}; mean - 0.68; std - 0.01
# 14 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 3, 'clf__n_neighbors': 16}; mean - 0.69; std - 0.01
# 15 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 3, 'clf__n_neighbors': 16}; mean - 0.70; std - 0.00
# 16 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 4, 'clf__n_neighbors': 16}; mean - 0.69; std - 0.01
# 17 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 4, 'clf__n_neighbors': 16}; mean - 0.69; std - 0.00
# 18 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 2, 'clf__n_neighbors': 32}; mean - 0.68; std - 0.01
# 19 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 2, 'clf__n_neighbors': 32}; mean - 0.68; std - 0.02
# 20 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 3, 'clf__n_neighbors': 32}; mean - 0.69; std - 0.01
# 21 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 3, 'clf__n_neighbors': 32}; mean - 0.70; std - 0.02
# 22 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 4, 'clf__n_neighbors': 32}; mean - 0.69; std - 0.01
# 23 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 4, 'clf__n_neighbors': 32}; mean - 0.70; std - 0.01
# 24 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 2, 'clf__n_neighbors': 32}; mean - 0.70; std - 0.03
# 25 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 2, 'clf__n_neighbors': 32}; mean - 0.71; std - 0.02
# 26 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 3, 'clf__n_neighbors': 32}; mean - 0.70; std - 0.01
# 27 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 3, 'clf__n_neighbors': 32}; mean - 0.70; std - 0.02
# 28 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 4, 'clf__n_neighbors': 32}; mean - 0.71; std - 0.01
# 29 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 4, 'clf__n_neighbors': 32}; mean - 0.71; std - 0.01
# 30 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 2, 'clf__n_neighbors': 32}; mean - 0.70; std - 0.02
# 31 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 2, 'clf__n_neighbors': 32}; mean - 0.71; std - 0.01
# 32 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 3, 'clf__n_neighbors': 32}; mean - 0.69; std - 0.01
# 33 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 3, 'clf__n_neighbors': 32}; mean - 0.70; std - 0.01
# 34 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 4, 'clf__n_neighbors': 32}; mean - 0.71; std - 0.00
# 35 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 4, 'clf__n_neighbors': 32}; mean - 0.71; std - 0.01
# 36 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 2, 'clf__n_neighbors': 64}; mean - 0.71; std - 0.02
# 37 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 2, 'clf__n_neighbors': 64}; mean - 0.71; std - 0.03
# 38 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 3, 'clf__n_neighbors': 64}; mean - 0.71; std - 0.02
# 39 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 3, 'clf__n_neighbors': 64}; mean - 0.71; std - 0.02
# 40 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 4, 'clf__n_neighbors': 64}; mean - 0.71; std - 0.01
# 41 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 4, 'clf__n_neighbors': 64}; mean - 0.71; std - 0.02
# 42 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 2, 'clf__n_neighbors': 64}; mean - 0.72; std - 0.02
# 43 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 2, 'clf__n_neighbors': 64}; mean - 0.71; std - 0.03
# 44 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 3, 'clf__n_neighbors': 64}; mean - 0.72; std - 0.03
# 45 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 3, 'clf__n_neighbors': 64}; mean - 0.72; std - 0.03
# 46 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 4, 'clf__n_neighbors': 64}; mean - 0.72; std - 0.02
# 47 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 4, 'clf__n_neighbors': 64}; mean - 0.71; std - 0.02
# 48 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 2, 'clf__n_neighbors': 64}; mean - 0.72; std - 0.02
# 49 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 2, 'clf__n_neighbors': 64}; mean - 0.71; std - 0.02
# 50 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 3, 'clf__n_neighbors': 64}; mean - 0.72; std - 0.02
# 51 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 3, 'clf__n_neighbors': 64}; mean - 0.72; std - 0.02
# 52 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 4, 'clf__n_neighbors': 64}; mean - 0.72; std - 0.02
# 53 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 4, 'clf__n_neighbors': 64}; mean - 0.72; std - 0.02
# 54 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 2, 'clf__n_neighbors': 128}; mean - 0.74; std - 0.02
# 55 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 2, 'clf__n_neighbors': 128}; mean - 0.72; std - 0.02
# 56 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 3, 'clf__n_neighbors': 128}; mean - 0.73; std - 0.03
# 57 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 3, 'clf__n_neighbors': 128}; mean - 0.72; std - 0.04
# 58 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 4, 'clf__n_neighbors': 128}; mean - 0.73; std - 0.03
# 59 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 4, 'clf__n_neighbors': 128}; mean - 0.73; std - 0.03
# 60 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 2, 'clf__n_neighbors': 128}; mean - 0.74; std - 0.03
# 61 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 2, 'clf__n_neighbors': 128}; mean - 0.74; std - 0.03
# 62 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 3, 'clf__n_neighbors': 128}; mean - 0.74; std - 0.04
# 63 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 3, 'clf__n_neighbors': 128}; mean - 0.74; std - 0.04
# 64 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 4, 'clf__n_neighbors': 128}; mean - 0.75; std - 0.02
# 65 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 4, 'clf__n_neighbors': 128}; mean - 0.74; std - 0.03
# 66 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 2, 'clf__n_neighbors': 128}; mean - 0.74; std - 0.02
# 67 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 2, 'clf__n_neighbors': 128}; mean - 0.74; std - 0.03
# 68 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 3, 'clf__n_neighbors': 128}; mean - 0.74; std - 0.02
# 69 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 3, 'clf__n_neighbors': 128}; mean - 0.73; std - 0.03
# 70 params - {'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 4, 'clf__n_neighbors': 128}; mean - 0.74; std - 0.02
# 71 params - {'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 4, 'clf__n_neighbors': 128}; mean - 0.75; std - 0.03
#              precision    recall  f1-score   support
#
#         neg       0.81      0.65      0.72       247
#         pos       0.72      0.85      0.78       253
#
# avg / total       0.76      0.75      0.75       500
#
# [[161  86]
#  [ 37 216]]

# %%
# K nearst neighbor
print ('======= Start Evaluation of KNN =======')
pipeline = Pipeline([
        ('vect', TfidfVectorizer(min_df=3, max_df=0.95)), # vectorization
        ('pca', TruncatedSVD()), # LSA
        ('clf', KNeighborsClassifier()), # KNN classifier
    ])

parameters = {
        'vect__ngram_range': [(1, 2), (1, 3)],
        'pca__n_components': range(3,10,2),
        'clf__n_neighbors': [16, 32, 64, 128],
    }

grid_search = GridSearchCV(pipeline, parameters, n_jobs=-1)
grid_search.fit(docs_train, y_train)

n_candidates = len(grid_search.cv_results_['params'])
for i in range(n_candidates):
    print(i, 'params - %s; mean - %0.2f; std - %0.2f'
             % (grid_search.cv_results_['params'][i],
                grid_search.cv_results_['mean_test_score'][i],
                grid_search.cv_results_['std_test_score'][i]))

y_predicted = grid_search.predict(docs_test)
print(metrics.classification_report(y_test, y_predicted, 
                                    target_names=dataset.target_names)) # classification result
cm = metrics.confusion_matrix(y_test, y_predicted) # confusion matrix
print(cm)
# Out:
# ======= Start Evaluation of KNN =======
# 0 params - {'vect__ngram_range': (1, 2), 'pca__n_components': 3, 'clf__n_neighbors': 16}; mean - 0.60; std - 0.03
# 1 params - {'vect__ngram_range': (1, 3), 'pca__n_components': 3, 'clf__n_neighbors': 16}; mean - 0.61; std - 0.03
# 2 params - {'vect__ngram_range': (1, 2), 'pca__n_components': 5, 'clf__n_neighbors': 16}; mean - 0.61; std - 0.01
# 3 params - {'vect__ngram_range': (1, 3), 'pca__n_components': 5, 'clf__n_neighbors': 16}; mean - 0.63; std - 0.01
# 4 params - {'vect__ngram_range': (1, 2), 'pca__n_components': 7, 'clf__n_neighbors': 16}; mean - 0.63; std - 0.01
# 5 params - {'vect__ngram_range': (1, 3), 'pca__n_components': 7, 'clf__n_neighbors': 16}; mean - 0.62; std - 0.01
# 6 params - {'vect__ngram_range': (1, 2), 'pca__n_components': 9, 'clf__n_neighbors': 16}; mean - 0.64; std - 0.03
# 7 params - {'vect__ngram_range': (1, 3), 'pca__n_components': 9, 'clf__n_neighbors': 16}; mean - 0.65; std - 0.04
# 8 params - {'vect__ngram_range': (1, 2), 'pca__n_components': 3, 'clf__n_neighbors': 32}; mean - 0.61; std - 0.03
# 9 params - {'vect__ngram_range': (1, 3), 'pca__n_components': 3, 'clf__n_neighbors': 32}; mean - 0.62; std - 0.04
# 10 params - {'vect__ngram_range': (1, 2), 'pca__n_components': 5, 'clf__n_neighbors': 32}; mean - 0.65; std - 0.02
# 11 params - {'vect__ngram_range': (1, 3), 'pca__n_components': 5, 'clf__n_neighbors': 32}; mean - 0.63; std - 0.02
# 12 params - {'vect__ngram_range': (1, 2), 'pca__n_components': 7, 'clf__n_neighbors': 32}; mean - 0.64; std - 0.01
# 13 params - {'vect__ngram_range': (1, 3), 'pca__n_components': 7, 'clf__n_neighbors': 32}; mean - 0.63; std - 0.01
# 14 params - {'vect__ngram_range': (1, 2), 'pca__n_components': 9, 'clf__n_neighbors': 32}; mean - 0.64; std - 0.02
# 15 params - {'vect__ngram_range': (1, 3), 'pca__n_components': 9, 'clf__n_neighbors': 32}; mean - 0.65; std - 0.02
# 16 params - {'vect__ngram_range': (1, 2), 'pca__n_components': 3, 'clf__n_neighbors': 64}; mean - 0.61; std - 0.03
# 17 params - {'vect__ngram_range': (1, 3), 'pca__n_components': 3, 'clf__n_neighbors': 64}; mean - 0.63; std - 0.03
# 18 params - {'vect__ngram_range': (1, 2), 'pca__n_components': 5, 'clf__n_neighbors': 64}; mean - 0.64; std - 0.02
# 19 params - {'vect__ngram_range': (1, 3), 'pca__n_components': 5, 'clf__n_neighbors': 64}; mean - 0.64; std - 0.03
# 20 params - {'vect__ngram_range': (1, 2), 'pca__n_components': 7, 'clf__n_neighbors': 64}; mean - 0.64; std - 0.01
# 21 params - {'vect__ngram_range': (1, 3), 'pca__n_components': 7, 'clf__n_neighbors': 64}; mean - 0.65; std - 0.01
# 22 params - {'vect__ngram_range': (1, 2), 'pca__n_components': 9, 'clf__n_neighbors': 64}; mean - 0.66; std - 0.03
# 23 params - {'vect__ngram_range': (1, 3), 'pca__n_components': 9, 'clf__n_neighbors': 64}; mean - 0.65; std - 0.03
# 24 params - {'vect__ngram_range': (1, 2), 'pca__n_components': 3, 'clf__n_neighbors': 128}; mean - 0.61; std - 0.03
# 25 params - {'vect__ngram_range': (1, 3), 'pca__n_components': 3, 'clf__n_neighbors': 128}; mean - 0.63; std - 0.04
# 26 params - {'vect__ngram_range': (1, 2), 'pca__n_components': 5, 'clf__n_neighbors': 128}; mean - 0.65; std - 0.04
# 27 params - {'vect__ngram_range': (1, 3), 'pca__n_components': 5, 'clf__n_neighbors': 128}; mean - 0.65; std - 0.02
# 28 params - {'vect__ngram_range': (1, 2), 'pca__n_components': 7, 'clf__n_neighbors': 128}; mean - 0.64; std - 0.02
# 29 params - {'vect__ngram_range': (1, 3), 'pca__n_components': 7, 'clf__n_neighbors': 128}; mean - 0.65; std - 0.02
# 30 params - {'vect__ngram_range': (1, 2), 'pca__n_components': 9, 'clf__n_neighbors': 128}; mean - 0.66; std - 0.02
# 31 params - {'vect__ngram_range': (1, 3), 'pca__n_components': 9, 'clf__n_neighbors': 128}; mean - 0.66; std - 0.02
#              precision    recall  f1-score   support
#
#         neg       0.61      0.81      0.70       247
#         pos       0.73      0.50      0.59       253
#
# avg / total       0.67      0.65      0.65       500
#
# [[201  46]
#  [127 126]]

# %%
# Random Forest
print ('======= Start Evaluation of Random Forest =======')
pipeline = Pipeline([
        ('vect', TfidfVectorizer()), # vectorization
        ('clf', RandomForestClassifier()), # random forest classifier
    ])

parameters = {
        'vect__ngram_range': [(1, 2), (1, 3)],
        'vect__min_df': [2, 3, 4],
        'vect__max_df': [0.98, 0.95, 0.92],
        'clf__n_estimators': [8, 16, 32, 64],
    }

grid_search = GridSearchCV(pipeline, parameters, n_jobs=-1)
grid_search.fit(docs_train, y_train)

n_candidates = len(grid_search.cv_results_['params'])
for i in range(n_candidates):
    print(i, 'params - %s; mean - %0.2f; std - %0.2f'
             % (grid_search.cv_results_['params'][i],
                grid_search.cv_results_['mean_test_score'][i],
                grid_search.cv_results_['std_test_score'][i]))

y_predicted = grid_search.predict(docs_test)
print(metrics.classification_report(y_test, y_predicted, 
                                    target_names=dataset.target_names)) # classification result
cm = metrics.confusion_matrix(y_test, y_predicted) # confusion matrix
print(cm)
# Out:
# ======= Start Evaluation of Random Forest =======
# 0 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 2}; mean - 0.62; std - 0.02
# 1 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 2}; mean - 0.64; std - 0.01
# 2 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 3}; mean - 0.63; std - 0.01
# 3 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 3}; mean - 0.62; std - 0.01
# 4 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 4}; mean - 0.64; std - 0.03
# 5 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 4}; mean - 0.64; std - 0.01
# 6 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 2}; mean - 0.62; std - 0.01
# 7 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 2}; mean - 0.61; std - 0.02
# 8 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 3}; mean - 0.60; std - 0.03
# 9 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 3}; mean - 0.63; std - 0.01
# 10 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 4}; mean - 0.65; std - 0.01
# 11 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 4}; mean - 0.64; std - 0.02
# 12 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 2}; mean - 0.63; std - 0.01
# 13 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 2}; mean - 0.60; std - 0.02
# 14 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 3}; mean - 0.63; std - 0.00
# 15 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 3}; mean - 0.64; std - 0.03
# 16 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 4}; mean - 0.66; std - 0.02
# 17 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 4}; mean - 0.61; std - 0.02
# 18 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 2}; mean - 0.65; std - 0.01
# 19 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 2}; mean - 0.66; std - 0.00
# 20 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 3}; mean - 0.67; std - 0.01
# 21 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 3}; mean - 0.66; std - 0.02
# 22 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 4}; mean - 0.67; std - 0.01
# 23 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 4}; mean - 0.67; std - 0.02
# 24 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 2}; mean - 0.67; std - 0.02
# 25 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 2}; mean - 0.66; std - 0.02
# 26 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 3}; mean - 0.67; std - 0.03
# 27 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 3}; mean - 0.67; std - 0.00
# 28 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 4}; mean - 0.65; std - 0.01
# 29 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 4}; mean - 0.68; std - 0.02
# 30 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 2}; mean - 0.68; std - 0.01
# 31 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 2}; mean - 0.66; std - 0.01
# 32 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 3}; mean - 0.67; std - 0.01
# 33 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 3}; mean - 0.66; std - 0.02
# 34 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 4}; mean - 0.69; std - 0.01
# 35 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 4}; mean - 0.64; std - 0.01
# 36 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 2}; mean - 0.72; std - 0.02
# 37 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 2}; mean - 0.70; std - 0.00
# 38 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 3}; mean - 0.72; std - 0.02
# 39 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 3}; mean - 0.71; std - 0.02
# 40 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 4}; mean - 0.73; std - 0.02
# 41 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 4}; mean - 0.71; std - 0.01
# 42 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 2}; mean - 0.70; std - 0.02
# 43 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 2}; mean - 0.71; std - 0.02
# 44 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 3}; mean - 0.72; std - 0.03
# 45 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 3}; mean - 0.70; std - 0.01
# 46 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 4}; mean - 0.71; std - 0.01
# 47 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 4}; mean - 0.72; std - 0.02
# 48 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 2}; mean - 0.71; std - 0.01
# 49 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 2}; mean - 0.71; std - 0.03
# 50 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 3}; mean - 0.72; std - 0.00
# 51 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 3}; mean - 0.71; std - 0.01
# 52 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 4}; mean - 0.73; std - 0.01
# 53 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 4}; mean - 0.72; std - 0.01
# 54 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 2}; mean - 0.75; std - 0.02
# 55 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 2}; mean - 0.74; std - 0.02
# 56 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 3}; mean - 0.74; std - 0.02
# 57 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 3}; mean - 0.74; std - 0.02
# 58 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 4}; mean - 0.75; std - 0.01
# 59 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 4}; mean - 0.75; std - 0.02
# 60 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 2}; mean - 0.75; std - 0.01
# 61 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 2}; mean - 0.74; std - 0.02
# 62 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 3}; mean - 0.75; std - 0.01
# 63 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 3}; mean - 0.75; std - 0.02
# 64 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 4}; mean - 0.77; std - 0.04
# 65 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 4}; mean - 0.77; std - 0.01
# 66 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 2}; mean - 0.76; std - 0.00
# 67 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 2}; mean - 0.72; std - 0.01
# 68 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 3}; mean - 0.77; std - 0.02
# 69 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 3}; mean - 0.75; std - 0.01
# 70 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 4}; mean - 0.75; std - 0.03
# 71 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 4}; mean - 0.75; std - 0.02
#              precision    recall  f1-score   support
#
#         neg       0.75      0.87      0.80       247
#         pos       0.85      0.71      0.77       253
#
# avg / total       0.80      0.79      0.79       500
#
# [[214  33]
#  [ 73 180]]

# %%
# Random Forest
print ('======= Start Evaluation of Random Forest =======')
pipeline = Pipeline([
        ('vect', TfidfVectorizer(min_df=3, max_df=0.95)), # vectorization
        ('pca', TruncatedSVD()), # LSA
        ('clf', RandomForestClassifier()), # random forest classifier
    ])

parameters = {
        'vect__ngram_range': [(1, 2), (1, 3)],
        'pca__n_components': range(3,10,2),
        'clf__n_estimators': [8, 16, 32, 64],
    }

grid_search = GridSearchCV(pipeline, parameters, n_jobs=-1)
grid_search.fit(docs_train, y_train)

n_candidates = len(grid_search.cv_results_['params'])
for i in range(n_candidates):
    print(i, 'params - %s; mean - %0.2f; std - %0.2f'
             % (grid_search.cv_results_['params'][i],
                grid_search.cv_results_['mean_test_score'][i],
                grid_search.cv_results_['std_test_score'][i]))

y_predicted = grid_search.predict(docs_test)
print(metrics.classification_report(y_test, y_predicted, 
                                    target_names=dataset.target_names)) # classification result
cm = metrics.confusion_matrix(y_test, y_predicted) # confusion matrix
print(cm)
# Out:
# ======= Start Evaluation of Random Forest =======
# 0 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 2), 'pca__n_components': 3}; mean - 0.57; std - 0.02
# 1 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 3), 'pca__n_components': 3}; mean - 0.56; std - 0.02
# 2 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 2), 'pca__n_components': 5}; mean - 0.61; std - 0.02
# 3 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 3), 'pca__n_components': 5}; mean - 0.60; std - 0.01
# 4 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 2), 'pca__n_components': 7}; mean - 0.61; std - 0.02
# 5 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 3), 'pca__n_components': 7}; mean - 0.60; std - 0.01
# 6 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 2), 'pca__n_components': 9}; mean - 0.64; std - 0.00
# 7 params - {'clf__n_estimators': 8, 'vect__ngram_range': (1, 3), 'pca__n_components': 9}; mean - 0.64; std - 0.01
# 8 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 2), 'pca__n_components': 3}; mean - 0.59; std - 0.03
# 9 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 3), 'pca__n_components': 3}; mean - 0.59; std - 0.03
# 10 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 2), 'pca__n_components': 5}; mean - 0.62; std - 0.01
# 11 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 3), 'pca__n_components': 5}; mean - 0.62; std - 0.02
# 12 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 2), 'pca__n_components': 7}; mean - 0.64; std - 0.02
# 13 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 3), 'pca__n_components': 7}; mean - 0.63; std - 0.01
# 14 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 2), 'pca__n_components': 9}; mean - 0.66; std - 0.00
# 15 params - {'clf__n_estimators': 16, 'vect__ngram_range': (1, 3), 'pca__n_components': 9}; mean - 0.63; std - 0.01
# 16 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 2), 'pca__n_components': 3}; mean - 0.59; std - 0.03
# 17 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 3), 'pca__n_components': 3}; mean - 0.60; std - 0.02
# 18 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 2), 'pca__n_components': 5}; mean - 0.62; std - 0.01
# 19 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 3), 'pca__n_components': 5}; mean - 0.62; std - 0.01
# 20 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 2), 'pca__n_components': 7}; mean - 0.65; std - 0.02
# 21 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 3), 'pca__n_components': 7}; mean - 0.65; std - 0.01
# 22 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 2), 'pca__n_components': 9}; mean - 0.66; std - 0.02
# 23 params - {'clf__n_estimators': 32, 'vect__ngram_range': (1, 3), 'pca__n_components': 9}; mean - 0.64; std - 0.02
# 24 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 2), 'pca__n_components': 3}; mean - 0.59; std - 0.01
# 25 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 3), 'pca__n_components': 3}; mean - 0.60; std - 0.03
# 26 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 2), 'pca__n_components': 5}; mean - 0.64; std - 0.01
# 27 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 3), 'pca__n_components': 5}; mean - 0.64; std - 0.02
# 28 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 2), 'pca__n_components': 7}; mean - 0.66; std - 0.00
# 29 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 3), 'pca__n_components': 7}; mean - 0.65; std - 0.01
# 30 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 2), 'pca__n_components': 9}; mean - 0.65; std - 0.02
# 31 params - {'clf__n_estimators': 64, 'vect__ngram_range': (1, 3), 'pca__n_components': 9}; mean - 0.65; std - 0.01
#              precision    recall  f1-score   support
#
#         neg       0.63      0.81      0.71       247
#         pos       0.74      0.55      0.63       253
#
# avg / total       0.69      0.67      0.67       500
#
# [[199  48]
#  [115 138]]

# %%
# Neural Network
print ('======= Start Evaluation of Neural Network =======')
pipeline = Pipeline([
        ('vect', TfidfVectorizer()), # vectorization
        ('clf', MLPClassifier()), # neural network
    ])

parameters = {
        'vect__ngram_range': [(1, 2), (1, 3)],
        'vect__min_df': [2, 3, 4],
        'vect__max_df': [0.98, 0.95, 0.92],
        'clf__alpha': [1e-5, 1e-4, 1e-3],
    }

grid_search = GridSearchCV(pipeline, parameters, n_jobs=-1)
grid_search.fit(docs_train, y_train)

n_candidates = len(grid_search.cv_results_['params'])
for i in range(n_candidates):
    print(i, 'params - %s; mean - %0.2f; std - %0.2f'
             % (grid_search.cv_results_['params'][i],
                grid_search.cv_results_['mean_test_score'][i],
                grid_search.cv_results_['std_test_score'][i]))

y_predicted = grid_search.predict(docs_test)
print(metrics.classification_report(y_test, y_predicted, 
                                    target_names=dataset.target_names)) # classification result
cm = metrics.confusion_matrix(y_test, y_predicted) # confusion matrix
print(cm)
# Out:
# ======= Start Evaluation of Neural Network =======
# 0 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 2}; mean - 0.84; std - 0.01
# 1 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 2}; mean - 0.83; std - 0.01
# 2 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 3}; mean - 0.83; std - 0.01
# 3 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 3}; mean - 0.83; std - 0.02
# 4 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 4}; mean - 0.84; std - 0.01
# 5 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 4}; mean - 0.85; std - 0.02
# 6 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 2}; mean - 0.83; std - 0.01
# 7 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 2}; mean - 0.83; std - 0.01
# 8 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 3}; mean - 0.83; std - 0.01
# 9 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 3}; mean - 0.83; std - 0.02
# 10 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 4}; mean - 0.84; std - 0.01
# 11 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 4}; mean - 0.84; std - 0.01
# 12 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 2}; mean - 0.83; std - 0.01
# 13 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 2}; mean - 0.83; std - 0.01
# 14 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 3}; mean - 0.83; std - 0.01
# 15 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 3}; mean - 0.83; std - 0.02
# 16 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 4}; mean - 0.84; std - 0.01
# 17 params - {'clf__alpha': 1e-05, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 4}; mean - 0.84; std - 0.02
# 18 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 2}; mean - 0.84; std - 0.01
# 19 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 2}; mean - 0.83; std - 0.01
# 20 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 3}; mean - 0.83; std - 0.01
# 21 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 3}; mean - 0.83; std - 0.02
# 22 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 4}; mean - 0.84; std - 0.01
# 23 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 4}; mean - 0.84; std - 0.01
# 24 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 2}; mean - 0.84; std - 0.01
# 25 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 2}; mean - 0.83; std - 0.01
# 26 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 3}; mean - 0.84; std - 0.01
# 27 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 3}; mean - 0.83; std - 0.01
# 28 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 4}; mean - 0.84; std - 0.01
# 29 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 4}; mean - 0.84; std - 0.01
# 30 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 2}; mean - 0.84; std - 0.01
# 31 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 2}; mean - 0.83; std - 0.01
# 32 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 3}; mean - 0.84; std - 0.01
# 33 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 3}; mean - 0.83; std - 0.01
# 34 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 4}; mean - 0.84; std - 0.01
# 35 params - {'clf__alpha': 0.0001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 4}; mean - 0.84; std - 0.02
# 36 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 2}; mean - 0.84; std - 0.01
# 37 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 2}; mean - 0.84; std - 0.01
# 38 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 3}; mean - 0.84; std - 0.01
# 39 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 3}; mean - 0.84; std - 0.01
# 40 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.98, 'vect__min_df': 4}; mean - 0.84; std - 0.01
# 41 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.98, 'vect__min_df': 4}; mean - 0.84; std - 0.02
# 42 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 2}; mean - 0.84; std - 0.01
# 43 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 2}; mean - 0.84; std - 0.01
# 44 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 3}; mean - 0.84; std - 0.01
# 45 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 3}; mean - 0.84; std - 0.02
# 46 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.95, 'vect__min_df': 4}; mean - 0.84; std - 0.01
# 47 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.95, 'vect__min_df': 4}; mean - 0.84; std - 0.01
# 48 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 2}; mean - 0.84; std - 0.01
# 49 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 2}; mean - 0.84; std - 0.01
# 50 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 3}; mean - 0.84; std - 0.01
# 51 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 3}; mean - 0.84; std - 0.02
# 52 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 2), 'vect__max_df': 0.92, 'vect__min_df': 4}; mean - 0.84; std - 0.01
# 53 params - {'clf__alpha': 0.001, 'vect__ngram_range': (1, 3), 'vect__max_df': 0.92, 'vect__min_df': 4}; mean - 0.84; std - 0.01
#              precision    recall  f1-score   support
#
#         neg       0.90      0.88      0.89       247
#         pos       0.89      0.91      0.90       253
#
# avg / total       0.90      0.90      0.90       500
#
# [[218  29]
#  [ 23 230]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-ebe8f3359adf> in <module>()
#      30
#      31 pip = grid_search.best_estimator_
# ---> 32 print(pip['clf'].n_layers_)
#
# TypeError: 'Pipeline' object is not subscriptable

# %%
pip = grid_search.best_estimator_
print(pip.named_steps['clf'].n_layers_)
# Out:
# 3

# %% [markdown]
# *------------------------
#
# ## Problem 4 (20 points): Open Ended Question:  Finding the right plot

# %% [markdown]
# * Can you find a two dimensional plot in which the positive and negative reviews are separated?
#     * This problem is hard since you will likely have thousands of features for review, and you will need to transform these thousands of features into just two numbers (so that you can make a 2D plot).
# * Note, I was not able to find such a plot myself!
#     * So, this problem is about **trying** but perhaps **not necessarily succeeding**!
# * I tried two things, neither of which worked very well.
#     * I first plotted the length of the review versus the number of features we compute that are in that review
#     * Second I used Principle Component Analysis on a subset of the features.
# * Can you do better than I did!?

# %%
from sklearn.decomposition import PCA
from sklearn.decomposition import FastICA
from sklearn.feature_selection import SelectFromModel
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
vector = TfidfVectorizer(min_df=3, max_df=0.95, ngram_range=(1,2))
word_vector = vector.fit_transform(dataset.data)

# %% [markdown]
# ### PCA

# %%
# LSA
pca = TruncatedSVD(n_components=2)
word_pca = pca.fit_transform(word_vector.todense())

for value, target in zip(word_pca, dataset.target):
    if target == 0:
        plt.plot(value[0], value[1], 'bo')
    else:
        plt.plot(value[0], value[1], 'rx')

# %%
pca = PCA(n_components=100)
word_pca = pca.fit_transform(word_vector.todense())
ratio = pca.explained_variance_ratio_

plt.plot(range(1,101,1),ratio*100,'bs')
plt.xlabel('Number of principal component')
plt.ylabel('Explained variance ratio')

# %% [markdown]
# ### Manifold

# %%
from sklearn.manifold import Isomap

iso = Isomap(n_neighbors=64, n_components=2)
low_d_feature = iso.fit_transform(word_vector.todense())

for value, target in zip(low_d_feature, dataset.target):
    if target == 0:
        plt.plot(value[0], value[1], 'bo')
    else:
        plt.plot(value[0], value[1], 'rx')

# %%
from sklearn.manifold import MDS

mds = MDS(n_components=2)
low_d_feature = mds.fit_transform(word_vector.todense())

for value, target in zip(low_d_feature, dataset.target):
    if target == 0:
        plt.plot(value[0], value[1], 'bo')
    else:
        plt.plot(value[0], value[1], 'rx')

# %%
from sklearn.manifold import locally_linear_embedding

low_d_feature = locally_linear_embedding(n_neighbors=64, n_components=2, X=word_vector.todense())

# %%
features = low_d_feature[0]

for value, target in zip(features, dataset.target):
    if target == 0:
        plt.plot(value[0], value[1], 'bo')
    else:
        plt.plot(value[0], value[1], 'rx')

# %%
from sklearn.manifold import SpectralEmbedding

se = SpectralEmbedding(n_components=2, affinity='nearest_neighbors', n_neighbors=64)
low_d_feature = se.fit_transform(word_vector.todense())

for value, target in zip(low_d_feature, dataset.target):
    if target == 0:
        plt.plot(value[0], value[1], 'bo')
    else:
        plt.plot(value[0], value[1], 'rx')

# %%
from sklearn.manifold import TSNE

se = TSNE(n_components=2, perplexity=32, init='pca')
low_d_feature = se.fit_transform(word_vector.todense())

for value, target in zip(low_d_feature, dataset.target):
    if target == 0:
        plt.plot(value[0], value[1], 'bo')
    else:
        plt.plot(value[0], value[1], 'rx')

# %% [markdown]
# ### Feature selection

# %%
# recall LinearSVC classifier
svc = LinearSVC(C=1000)

selector = SelectFromModel(estimator=svc)
new_feature = selector.fit_transform(word_vector, dataset.target)

pca = PCA()

while True:
    new_feature = selector.fit_transform(new_feature, dataset.target)
    word_pca = pca.fit_transform(new_feature.todense())
    ratio = pca.explained_variance_ratio_
    if np.sum(ratio[:2]) >= 0.13:
        break
    

selector.fit_transform(new_feature, dataset.target)

print(np.size(word_vector.todense()[0,:]))
print(np.size(new_feature.todense()[0,:]))

for value, target in zip(word_pca[:,:2], dataset.target):
    if target == 0:
        plt.plot(value[0], value[1], 'bo')
    else:
        plt.plot(value[0], value[1], 'rx')
# Out:
# 81468
# 42

# %%
plt.plot(range(1,len(ratio)+1,1),ratio*100,'bs')
plt.xlabel('Number of principal component')
plt.ylabel('Explained variance ratio')

# %%
svc = selector.estimator_
y_predicted = svc.predict(new_feature)
cm = metrics.confusion_matrix(dataset.target, y_predicted) # confusion matrix
print(cm)
# Out:
# [[328 672]
#  [ 33 967]]

# %%
pca = PCA()
word_pca = pca.fit_transform(new_feature.todense())
ratio = pca.explained_variance_ratio_

plt.plot(range(1,len(ratio)+1,1),ratio*100,'bs')
plt.xlabel('Number of principal component')
plt.ylabel('Explained variance ratio')

# %%
for value, target in zip(word_pca[:,:2], dataset.target):
    if target == 0:
        plt.plot(value[0], value[1], 'bo')
    else:
        plt.plot(value[0], value[1], 'rx')

# %%
# recall MLP
rfc = RandomForestClassifier(n_estimators=64)

selector = SelectFromModel(estimator=rfc)
new_feature = selector.fit_transform(word_vector, dataset.target)

pca = PCA()
word_pca = pca.fit_transform(new_feature.todense())
ratio = pca.explained_variance_ratio_

i = 1

while True:
    if np.sum(ratio[:2]) < 0.3:
        new_feature = selector.fit_transform(new_feature, dataset.target)
        word_pca = pca.fit_transform(new_feature.todense())
        ratio = pca.explained_variance_ratio_
    elif len(ratio) > 10:
        new_feature = selector.fit_transform(new_feature, dataset.target)
        word_pca = pca.fit_transform(new_feature.todense())
        ratio = pca.explained_variance_ratio_
        plt.figure(i)
        for value, target in zip(word_pca[:,:2], dataset.target):
            if target == 0:
                plt.plot(value[0], value[1], 'bo')
            else:
                plt.plot(value[0], value[1], 'rx')
        i += 1
    else:
        plt.figure(i)
        for value, target in zip(word_pca[:,:2], dataset.target):
            if target == 0:
                plt.plot(value[0], value[1], 'bo')
            else:
                plt.plot(value[0], value[1], 'rx')
        i += 1
        break

# %%
ratio
# Out:
# array([ 0.42286859,  0.20344176,  0.13944699,  0.1269758 ,  0.10726686])

# %%
sum(ratio[:2])
# Out:
# 0.62631035168625904

# %%
# ICA
ica = FastICA(n_components=2, whiten=True)
word_pca = ica.fit_transform(word_vector.todense())

for value, target in zip(word_pca, dataset.target):
    if target == 0:
        plt.plot(value[0], value[1], 'bo')
    else:
        plt.plot(value[0], value[1], 'rx')

# %% [markdown]
# ### The part below is using semantic orientation analysis. It requires lots of computation resource and always failed in laptop. Don't rerun it on your own computer.

# %%
import pandas as pd
import nltk
import re
import string
from collections import defaultdict
from collections import Counter
import numpy as np



# load words pool from Bing Liu
pos_pool = []
neg_pool = []

lines = open('./positive-words.txt', encoding='iso-8859-1').readlines()
for line in lines:
    pos_pool.append(line[:-1])
    
lines = open('./negative-words.txt', encoding='iso-8859-1').readlines()
for line in lines:
    neg_pool.append(line[:-1])



# function to extract words inside the tweet
def extract_word(content):
    words = [e.lower() for e in nltk.tokenize.word_tokenize(content) 
             if ((len(e) >= 3) and (e not in stop))]
    return (words)



# build word counter, co-occurance matrix
com = defaultdict(lambda: defaultdict(int))
stop = nltk.corpus.stopwords.words('english') + list(string.punctuation)
words_pool = []

for data in dataset.data:
    word_list = extract_word(data.decode('utf-8'))
    
    words_pool += word_list # build words pool
    
    for i in range(len(word_list)-1): # build co-occurance matrix
        for j in range(i+1, len(word_list)):
            w1, w2 = sorted([word_list[i], word_list[j]])
            if w1 != w2:
                com[w1][w2] += 1

words_counter = Counter(words_pool)



# compute word prob
p_w = {}
p_com = defaultdict(lambda : defaultdict(int))
n_pool = float(len(words_pool))
 
for word, n in words_counter.items():
    p_w[word] = n / n_pool
    for cow in com[word]:
        p_com[word][cow] = com[word][cow] / n_pool

        
               
# compute pmi
pmi = defaultdict(lambda : defaultdict(int))
for w1 in p_w:
    for w2 in com[w1]:
        denom = p_w[w1] * p_w[w2]
        pmi[w1][w2] = np.log2(p_com[w1][w2] / denom)

# compute pos/neg orientation of each review
SO_m = {}
for word, n in p_w.items():
    positive_assoc = sum(pmi[word][tx] for tx in pos_pool)
    negative_assoc = sum(pmi[word][tx] for tx in neg_pool)
    SO_m[word] = positive_assoc - negative_assoc

# %%
pos_count = []
neg_count = []
for data in dataset.data:
    word_list = extract_word(data.decode('utf-8'))
    pos_orien = 0
    neg_orien = 0
    for word in word_list:
        if (SO_m[word] > pos_orien):
            pos_orien = SO_m[word]
        if (SO_m[word] < neg_orien):
            neg_orien = SO_m[word]
    pos_count.append(pos_orien)
    neg_count.append(neg_orien)

for pos, neg, target in zip(pos_count, neg_count, dataset.target):
    if target == 0:
        plt.plot(pos, neg, 'bo')
    else:
        plt.plot(pos, neg, 'rx')

# %%
pos_count = []
neg_count = []
for data in dataset.data:
    word_list = extract_word(data.decode('utf-8'))
    pos_orien = []
    neg_orien = []
    for word in word_list:
        if (SO_m[word] > 0):
            pos_orien.append(SO_m[word])
        if (SO_m[word] < 0):
            neg_orien.append(SO_m[word])
    pos_count.append(np.mean(pos_orien))
    neg_count.append(np.mean(neg_orien))
# Out:
# /home/guanxiong/anaconda2/envs/py35/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# /home/guanxiong/anaconda2/envs/py35/lib/python3.5/site-packages/numpy/core/_methods.py:70: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
for pos, neg, target in zip(pos_count, neg_count, dataset.target):
    if target == 0:
        plt.plot(pos, neg, 'bo')
    else:
        plt.plot(pos, neg, 'rx')

# %%
X = []
Y = []
for data in dataset.data:
    word_list = extract_word(data.decode('utf-8'))
    pos_orien = []
    neg_orien = []
    for word in word_list:
        if (SO_m[word] > 0):
            pos_orien.append(SO_m[word])
        if (SO_m[word] < 0):
            neg_orien.append(SO_m[word])
    X.append(np.sum(pos_orien))
    Y.append(np.sum(neg_orien))

for x, y, target in zip(X, Y, dataset.target):
    if target == 0:
        plt.plot(x, y, 'bo')
    else:
        plt.plot(x, y, 'rx')

# %% [markdown]
# # Report: communicate the results (20 points)
#
# (1) (5 points) What data you collected?
#
# (2) (5 points) Why this topic is interesting or important to you? (Motivations)
#
# (3) (5 points) How did you analyse the data?
#
# (4) (5 points) What did you find in the data?
# (please include figures or tables in the report, but no source code)

# %% [markdown]
# # Slides (for 10 minutes of presentation) (20 points)
#
#
# 1. (5 points) Motivation about the data collection, why the topic is interesting to you.
#
# 2. (10 points) Communicating Results (figure/table)
#
# 3. (5 points) Story telling (How all the parts (data, analysis, result) fit together as a story?)

# %% [markdown]
# *-----------------
# # Done
#
# All set!
#
# ** What do you need to submit?**
#
# * **Notebook File**: Save this IPython notebook, and find the notebook file in your folder (for example, "filename.ipynb"). This is the file you need to submit. Please make sure all the plotted tables and figures are in the notebook. If you used "ipython notebook --pylab=inline" to open the notebook, all the figures and tables should have shown up in the notebook.
#
#
# * **PPT Slides**: please prepare PPT slides (for 10 minutes' talk) to present about the case study . We will ask two teams which are randomly selected to present their case studies in class for this case study.
#
# * ** Report**: please prepare a report (less than 10 pages) to report what you found in the data.
#     * What is the relationship between this topic and Business Intelligence?
#     * How did you analyse the data?
#     * What did you find in the data?
#     * What conjectures did you make and how did you support or disprove them using data?
#     * Did you find anything suprising in the data?
#     * What business decision do you think this data could help answer?  Why?
#
#    (please include figures or tables in the report, **but no source code**)
#
# *Please compress all the files into a single zipped file.*
#
#
# ** How to submit: **
#
#         Send an email to rcpaffenroth@wpi.edu and wliu3@wpi.edu with the subject: "[DS501] Case study 3-TEAM NUMBER ???".
