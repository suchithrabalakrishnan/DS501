# %% [markdown]
# # Example 1. Authorizing an application to access Twitter account data

# %%
import twitter
# Go to http://dev.twitter.com/apps/new to create an app and get values
# for these credentials, which you'll need to provide in place of these
# empty string values that are defined as placeholders.
# See https://dev.twitter.com/docs/auth/oauth for more information 
# on Twitter's OAuth implementation.

CONSUMER_KEY = 'Tx8GozuzaraJO89LypsTqFUNM'
CONSUMER_SECRET ='uC0KPaRZjGY0qoNJAxBQb0jbb3Us4DXJVKFCP1qtSfjFgbRvd0'
OAUTH_TOKEN = '571213367-BC7MYnWpLbvy2AYhvqCu6Fh1EIeFasPxo0Y8uBEn'
OAUTH_TOKEN_SECRET = 'KA9GddiLbVwummLoSGmDYMNQFVaR3P4YiGo7Zs6D5e7Qz'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x00000268EBFC5C18>

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 2. Retrieving trends

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print(world_trends)
print()
print(us_trends)
# Out:
# [{'created_at': '2016-09-04T19:54:33Z', 'as_of': '2016-09-04T20:02:24Z', 'locations': [{'woeid': 1, 'name': 'Worldwide'}], 'trends': [{'query': '%23WINGS', 'url': 'http://twitter.com/search?q=%23WINGS', 'promoted_content': None, 'tweet_volume': 468788, 'name': '#WINGS'}, {'query': '%23zg16', 'url': 'http://twitter.com/search?q=%23zg16', 'promoted_content': None, 'tweet_volume': None, 'name': '#zg16'}, {'query': '%23%D9%84%D9%88_%D8%A7%D9%84%D9%82%D8%AA%D9%84_%D8%AD%D9%84%D8%A7%D9%84_%D8%A8%D8%AA%D9%82%D8%AA%D9%84_%D9%85%D9%86', 'url': 'http://twitter.com/search?q=%23%D9%84%D9%88_%D8%A7%D9%84%D9%82%D8%AA%D9%84_%D8%AD%D9%84%D8%A7%D9%84_%D8%A8%D8%AA%D9%82%D8%AA%D9%84_%D9%85%D9%86', 'promoted_content': None, 'tweet_volume': 23076, 'name': '#لو_القتل_حلال_بتقتل_من'}, {'query': '%23WeAreReadyForSoloNiall', 'url': 'http://twitter.com/search?q=%23WeAreReadyForSoloNiall', 'promoted_content': None, 'tweet_volume': 173258, 'name': '#WeAreReadyForSoloNiall'}, {'query': '%23NORGER', 'url': 'http://twitter.com/search?q=%23NORGER', 'promoted_content': None, 'tweet_volume': 21606, 'name': '#NORGER'}, {'query': 'Camilo', 'url': 'http://twitter.com/search?q=Camilo', 'promoted_content': None, 'tweet_volume': 12617, 'name': 'Camilo'}, {'query': '%2214binVatan+HaininiTutukla%22', 'url': 'http://twitter.com/search?q=%2214binVatan+HaininiTutukla%22', 'promoted_content': None, 'tweet_volume': 37198, 'name': '14binVatan HaininiTutukla'}, {'query': '%22Louis+Tomlinson%22', 'url': 'http://twitter.com/search?q=%22Louis+Tomlinson%22', 'promoted_content': None, 'tweet_volume': 38506, 'name': 'Louis Tomlinson'}, {'query': 'Splyce', 'url': 'http://twitter.com/search?q=Splyce', 'promoted_content': None, 'tweet_volume': 28853, 'name': 'Splyce'}, {'query': '%23SLOENG', 'url': 'http://twitter.com/search?q=%23SLOENG', 'promoted_content': None, 'tweet_volume': 34331, 'name': '#SLOENG'}, {'query': '%23MessiEnPolemica', 'url': 'http://twitter.com/search?q=%23MessiEnPolemica', 'promoted_content': None, 'tweet_volume': 17317, 'name': '#MessiEnPolemica'}, {'query': '%23HangiA%C5%9FkAdilki', 'url': 'http://twitter.com/search?q=%23HangiA%C5%9FkAdilki', 'promoted_content': None, 'tweet_volume': 18347, 'name': '#HangiAşkAdilki'}, {'query': '%23ElianaAoVivo', 'url': 'http://twitter.com/search?q=%23ElianaAoVivo', 'promoted_content': None, 'tweet_volume': None, 'name': '#ElianaAoVivo'}, {'query': '%23%D9%81%D9%8A_%D9%83%D9%84_%D8%B9%D8%B1%D8%B3', 'url': 'http://twitter.com/search?q=%23%D9%81%D9%8A_%D9%83%D9%84_%D8%B9%D8%B1%D8%B3', 'promoted_content': None, 'tweet_volume': 34302, 'name': '#في_كل_عرس'}, {'query': '%23Tatort', 'url': 'http://twitter.com/search?q=%23Tatort', 'promoted_content': None, 'tweet_volume': None, 'name': '#Tatort'}, {'query': '%23KAZPOL', 'url': 'http://twitter.com/search?q=%23KAZPOL', 'promoted_content': None, 'tweet_volume': 49230, 'name': '#KAZPOL'}, {'query': '%23HowToConfuseAMillennial', 'url': 'http://twitter.com/search?q=%23HowToConfuseAMillennial', 'promoted_content': None, 'tweet_volume': 111757, 'name': '#HowToConfuseAMillennial'}, {'query': '%23WeLoveYouCalum', 'url': 'http://twitter.com/search?q=%23WeLoveYouCalum', 'promoted_content': None, 'tweet_volume': 12739, 'name': '#WeLoveYouCalum'}, {'query': '%23Mesaza', 'url': 'http://twitter.com/search?q=%23Mesaza', 'promoted_content': None, 'tweet_volume': 18427, 'name': '#Mesaza'}, {'query': '%23ltwmv', 'url': 'http://twitter.com/search?q=%23ltwmv', 'promoted_content': None, 'tweet_volume': 45578, 'name': '#ltwmv'}, {'query': '%23TipsForYear7s', 'url': 'http://twitter.com/search?q=%23TipsForYear7s', 'promoted_content': None, 'tweet_volume': 14466, 'name': '#TipsForYear7s'}, {'query': '%23%D8%A7%D9%85%D8%AA%D8%B9_%D9%84%D8%A7%D8%B9%D8%A8_%D8%A8%D9%81%D8%B1%D9%8A%D9%82%D9%83', 'url': 'http://twitter.com/search?q=%23%D8%A7%D9%85%D8%AA%D8%B9_%D9%84%D8%A7%D8%B9%D8%A8_%D8%A8%D9%81%D8%B1%D9%8A%D9%82%D9%83', 'promoted_content': None, 'tweet_volume': None, 'name': '#امتع_لاعب_بفريقك'}, {'query': '%23Arkad ...
#
# [{'created_at': '2016-09-04T19:59:39Z', 'as_of': '2016-09-04T20:02:25Z', 'locations': [{'woeid': 23424977, 'name': 'United States'}], 'trends': [{'query': '%23HowToConfuseAMillennial', 'url': 'http://twitter.com/search?q=%23HowToConfuseAMillennial', 'promoted_content': None, 'tweet_volume': 113102, 'name': '#HowToConfuseAMillennial'}, {'query': '%23SundayFunday', 'url': 'http://twitter.com/search?q=%23SundayFunday', 'promoted_content': None, 'tweet_volume': 16162, 'name': '#SundayFunday'}, {'query': '%23FakeBirthdayFacts', 'url': 'http://twitter.com/search?q=%23FakeBirthdayFacts', 'promoted_content': None, 'tweet_volume': None, 'name': '#FakeBirthdayFacts'}, {'query': '%23WeAreReadyForSoloNiall', 'url': 'http://twitter.com/search?q=%23WeAreReadyForSoloNiall', 'promoted_content': None, 'tweet_volume': 174685, 'name': '#WeAreReadyForSoloNiall'}, {'query': '%23HappyBirthdayBeyonce', 'url': 'http://twitter.com/search?q=%23HappyBirthdayBeyonce', 'promoted_content': None, 'tweet_volume': 389606, 'name': '#HappyBirthdayBeyonce'}, {'query': 'Splyce', 'url': 'http://twitter.com/search?q=Splyce', 'promoted_content': None, 'tweet_volume': 29833, 'name': 'Splyce'}, {'query': '%22Political+Correctness%22', 'url': 'http://twitter.com/search?q=%22Political+Correctness%22', 'promoted_content': None, 'tweet_volume': 17890, 'name': 'Political Correctness'}, {'query': 'Kimball', 'url': 'http://twitter.com/search?q=Kimball', 'promoted_content': None, 'tweet_volume': None, 'name': 'Kimball'}, {'query': '%22Dr.+Collins%22', 'url': 'http://twitter.com/search?q=%22Dr.+Collins%22', 'promoted_content': None, 'tweet_volume': None, 'name': 'Dr. Collins'}, {'query': 'Lackey', 'url': 'http://twitter.com/search?q=Lackey', 'promoted_content': None, 'tweet_volume': None, 'name': 'Lackey'}, {'query': 'Wozniacki', 'url': 'http://twitter.com/search?q=Wozniacki', 'promoted_content': None, 'tweet_volume': None, 'name': 'Wozniacki'}, {'query': 'Adrianza', 'url': 'http://twitter.com/search?q=Adrianza', 'promoted_content': None, 'tweet_volume': None, 'name': 'Adrianza'}, {'query': '%22Wade+Miley%22', 'url': 'http://twitter.com/search?q=%22Wade+Miley%22', 'promoted_content': None, 'tweet_volume': None, 'name': 'Wade Miley'}, {'query': '%22Lauren+Holiday%22', 'url': 'http://twitter.com/search?q=%22Lauren+Holiday%22', 'promoted_content': None, 'tweet_volume': None, 'name': 'Lauren Holiday'}, {'query': '%22Brian+Dozier%22', 'url': 'http://twitter.com/search?q=%22Brian+Dozier%22', 'promoted_content': None, 'tweet_volume': None, 'name': 'Brian Dozier'}, {'query': '%22Byron+Buxton%22', 'url': 'http://twitter.com/search?q=%22Byron+Buxton%22', 'promoted_content': None, 'tweet_volume': None, 'name': 'Byron Buxton'}, {'query': '%22Lucas+Pouille%22', 'url': 'http://twitter.com/search?q=%22Lucas+Pouille%22', 'promoted_content': None, 'tweet_volume': None, 'name': 'Lucas Pouille'}, {'query': '%22Demaryius+Thomas%22', 'url': 'http://twitter.com/search?q=%22Demaryius+Thomas%22', 'promoted_content': None, 'tweet_volume': None, 'name': 'Demaryius Thomas'}, {'query': '%22Rahim+Moore%22', 'url': 'http://twitter.com/search?q=%22Rahim+Moore%22', 'promoted_content': None, 'tweet_volume': None, 'name': 'Rahim Moore'}, {'query': '%22Jumbo+Diaz%22', 'url': 'http://twitter.com/search?q=%22Jumbo+Diaz%22', 'promoted_content': None, 'tweet_volume': None, 'name': 'Jumbo Diaz'}, {'query': '%22Soledad+O%27Brien%22', 'url': 'http://twitter.com/search?q=%22Soledad+O%27Brien%22', 'promoted_content': None, 'tweet_volume': None, 'name': "Soledad O'Brien"}, {'query': '%23DebbieDownerASongOrMovie', 'url': 'http://twitter.com/search?q=%23DebbieDownerASongOrMovie', 'promoted_content': None, 'tweet_volume': None, 'name': '#DebbieDownerASongOrMovie'}, {'query': '%23obsessionstonight', 'url': 'http://twitter.com/search?q=%23obsessionstonight', 'promoted_content': None, 'tweet_volume': None, 'name': '#obsessionstonight'}, {'query': '%23IndyCarGP', 'url': 'http://twitter.com/search?q=%23IndyCarGP', 'promoted_cont ...

# %%
import json
data= json.dumps(us_trends, indent=1)

file = open('foo.txt','w')
file.write(data)
file.close()

# %%
file = open('foo.txt','r')
foo = file.read()
d = json.loads(foo)

print(len(d))
print(d[0].keys())
print(len(d[0]['trends']))
print(d[0]['trends'][27])
# Out:
# 1
# dict_keys(['created_at', 'as_of', 'locations', 'trends'])
# 50
# {'query': '%23LondonsBurning', 'url': 'http://twitter.com/search?q=%23LondonsBurning', 'promoted_content': None, 'name': '#LondonsBurning', 'tweet_volume': None}

# %%
a= [1,2,3,4]
print(a)
print(a[0])
# Out:
# [1, 2, 3, 4]
# 1

# %%
b={'randy':47,'tyler':'cool'}
print(b['randy'])
print(b.keys())
# Out:
# 47
# dict_keys(['tyler', 'randy'])

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

#print(json.dumps(world_trends, indent=1))
print(json.dumps(us_trends, indent=1))
# Out:
# [
#  {
#   "created_at": "2016-09-04T19:59:39Z",
#   "as_of": "2016-09-04T20:02:25Z",
#   "locations": [
#    {
#     "woeid": 23424977,
#     "name": "United States"
#    }
#   ],
#   "trends": [
#    {
#     "query": "%23HowToConfuseAMillennial",
#     "url": "http://twitter.com/search?q=%23HowToConfuseAMillennial",
#     "promoted_content": null,
#     "tweet_volume": 113102,
#     "name": "#HowToConfuseAMillennial"
#    },
#    {
#     "query": "%23SundayFunday",
#     "url": "http://twitter.com/search?q=%23SundayFunday",
#     "promoted_content": null,
#     "tweet_volume": 16162,
#     "name": "#SundayFunday"
#    },
#    {
#     "query": "%23FakeBirthdayFacts",
#     "url": "http://twitter.com/search?q=%23FakeBirthdayFacts",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#FakeBirthdayFacts"
#    },
#    {
#     "query": "%23WeAreReadyForSoloNiall",
#     "url": "http://twitter.com/search?q=%23WeAreReadyForSoloNiall",
#     "promoted_content": null,
#     "tweet_volume": 174685,
#     "name": "#WeAreReadyForSoloNiall"
#    },
#    {
#     "query": "%23HappyBirthdayBeyonce",
#     "url": "http://twitter.com/search?q=%23HappyBirthdayBeyonce",
#     "promoted_content": null,
#     "tweet_volume": 389606,
#     "name": "#HappyBirthdayBeyonce"
#    },
#    {
#     "query": "Splyce",
#     "url": "http://twitter.com/search?q=Splyce",
#     "promoted_content": null,
#     "tweet_volume": 29833,
#     "name": "Splyce"
#    },
#    {
#     "query": "%22Political+Correctness%22",
#     "url": "http://twitter.com/search?q=%22Political+Correctness%22",
#     "promoted_content": null,
#     "tweet_volume": 17890,
#     "name": "Political Correctness"
#    },
#    {
#     "query": "Kimball",
#     "url": "http://twitter.com/search?q=Kimball",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "Kimball"
#    },
#    {
#     "query": "%22Dr.+Collins%22",
#     "url": "http://twitter.com/search?q=%22Dr.+Collins%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "Dr. Collins"
#    },
#    {
#     "query": "Lackey",
#     "url": "http://twitter.com/search?q=Lackey",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "Lackey"
#    },
#    {
#     "query": "Wozniacki",
#     "url": "http://twitter.com/search?q=Wozniacki",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "Wozniacki"
#    },
#    {
#     "query": "Adrianza",
#     "url": "http://twitter.com/search?q=Adrianza",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "Adrianza"
#    },
#    {
#     "query": "%22Wade+Miley%22",
#     "url": "http://twitter.com/search?q=%22Wade+Miley%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "Wade Miley"
#    },
#    {
#     "query": "%22Lauren+Holiday%22",
#     "url": "http://twitter.com/search?q=%22Lauren+Holiday%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "Lauren Holiday"
#    },
#    {
#     "query": "%22Brian+Dozier%22",
#     "url": "http://twitter.com/search?q=%22Brian+Dozier%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "Brian Dozier"
#    },
#    {
#     "query": "%22Byron+Buxton%22",
#     "url": "http://twitter.com/search?q=%22Byron+Buxton%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "Byron Buxton"
#    },
#    {
#     "query": "%22Lucas+Pouille%22",
#     "url": "http://twitter.com/search?q=%22Lucas+Pouille%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "Lucas Pouille"
#    },
#    {
#     "query": "%22Demaryius+Thomas%22",
#     "url": "http://twitter.com/search?q=%22Demaryius+Thomas%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "Demaryius Thomas"
#    },
#    {
#     "query": "%22Rahim+Moore%22",
#     "url": "http://twitter.com/search?q=%22Rahim+Moore%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "Rahim Moore"
#    },
#    {
#     "query": "%22Jumbo+Diaz%22",
#     "url": "http://twitter.com/search?q=%22Jumbo+Diaz%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "Jumbo Diaz"
#    },
#    {
#     "query": "%22Soledad+O%27Brien%22",
#     "url": "http://twitter.com/search?q=%22Soledad+O%27Brien%22",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "Soledad O'Brien"
#    },
#    {
#     "query": "%23DebbieDownerASongOrMovie",
#     "url": "http://twitter.com/search?q=%23DebbieDownerASongOrMovie",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#DebbieDownerASongOrMovie"
#    },
#    {
#     "query": "%23obsessionstonight",
#     "url": "http://twitter.com/search?q=%23obsessionstonight",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#obsessionstonight"
#    },
#    {
#     "query": "%23IndyCarGP",
#     "url": "http://twitter.com/search?q=%23IndyCarGP",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#IndyCarGP"
#    },
#    {
#     "query": "%23ItsBestIfWe",
#     "url": "http://twitter.com/search?q=%23ItsBestIfWe",
#     "promoted_content": null,
#     "tweet_volume": 10917,
#     "name": "#ItsBestIfWe"
#    },
#    {
#     "query": "%23PAXRUMBLE",
#     "url": "http://twitter.com/search?q=%23PAXRUMBLE",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#PAXRUMBLE"
#    },
#    {
#     "query": "%23WeLoveYouCalum",
#     "url": "http://twitter.com/search?q=%23WeLoveYouCalum",
#     "promoted_content": null,
#     "tweet_volume": 13092,
#     "name": "#WeLoveYouCalum"
#    },
#    {
#     "query": "%23LondonsBurning",
#     "url": "http://twitter.com/search?q=%23LondonsBurning",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#LondonsBurning"
#    },
#    {
#     "query": "%23ThingsToDoAtARedLight",
#     "url": "http://twitter.com/search?q=%23ThingsToDoAtARedLight",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#ThingsToDoAtARedLight"
#    },
#    {
#     "query": "%23BackToSchoolSongs",
#     "url": "http://twitter.com/search?q=%23BackToSchoolSongs",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#BackToSchoolSongs"
#    },
#    {
#     "query": "%23WINGS",
#     "url": "http://twitter.com/search?q=%23WINGS",
#     "promoted_content": null,
#     "tweet_volume": 471950,
#     "name": "#WINGS"
#    },
#    {
#     "query": "%23SLFLIrvine",
#     "url": "http://twitter.com/search?q=%23SLFLIrvine",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#SLFLIrvine"
#    },
#    {
#     "query": "%23DolansMakeMeSmile",
#     "url": "http://twitter.com/search?q=%23DolansMakeMeSmile",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#DolansMakeMeSmile"
#    },
#    {
#     "query": "%23SLOENG",
#     "url": "http://twitter.com/search?q=%23SLOENG",
#     "promoted_content": null,
#     "tweet_volume": 34509,
#     "name": "#SLOENG"
#    },
#    {
#     "query": "%23NORGER",
#     "url": "http://twitter.com/search?q=%23NORGER",
#     "promoted_content": null,
#     "tweet_volume": 21993,
#     "name": "#NORGER"
#    },
#    {
#     "query": "%23OTHERtone",
#     "url": "http://twitter.com/search?q=%23OTHERtone",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#OTHERtone"
#    },
#    {
#     "query": "%23NationalWildlifeDay",
#     "url": "http://twitter.com/search?q=%23NationalWildlifeDay",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#NationalWildlifeDay"
#    },
#    {
#     "query": "%23SVKENG",
#     "url": "http://twitter.com/search?q=%23SVKENG",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#SVKENG"
#    },
#    {
#     "query": "%23AMJoy",
#     "url": "http://twitter.com/search?q=%23AMJoy",
#     "promoted_content": null,
#     "tweet_volume": 18141,
#     "name": "#AMJoy"
#    },
#    {
#     "query": "%23NALCS",
#     "url": "http://twitter.com/search?q=%23NALCS",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#NALCS"
#    },
#    {
#     "query": "%23radglowspoil",
#     "url": "http://twitter.com/search?q=%23radglowspoil",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#radglowspoil"
#    },
#    {
#     "query": "%23EVOLutiontour",
#     "url": "http://twitter.com/search?q=%23EVOLutiontour",
#     "promoted_content": null,
#     "tweet_volume": 10016,
#     "name": "#EVOLutiontour"
#    },
#    {
#     "query": "%23Silverado250",
#     "url": "http://twitter.com/search?q=%23Silverado250",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#Silverado250"
#    },
#    {
#     "query": "%23NDvsTex",
#     "url": "http://twitter.com/search?q=%23NDvsTex",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#NDvsTex"
#    },
#    {
#     "query": "%23shawolselcaday",
#     "url": "http://twitter.com/search?q=%23shawolselcaday",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#shawolselcaday"
#    },
#    {
#     "query": "%23MakeAMovieArrogant",
#     "url": "http://twitter.com/search?q=%23MakeAMovieArrogant",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#MakeAMovieArrogant"
#    },
#    {
#     "query": "%23TCMBacklot",
#     "url": "http://twitter.com/search?q=%23TCMBacklot",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#TCMBacklot"
#    },
#    {
#     "query": "%23MyFavChildhoodCartoon",
#     "url": "http://twitter.com/search?q=%23MyFavChildhoodCartoon",
#     "promoted_content": null,
#     "tweet_volume": 58966,
#     "name": "#MyFavChildhoodCartoon"
#    },
#    {
#     "query": "%23BojanglesSo500",
#     "url": "http://twitter.com/search?q=%23BojanglesSo500",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#BojanglesSo500"
#    },
#    {
#     "query": "%23NoisyAndFamous",
#     "url": "http://twitter.com/search?q=%23NoisyAndFamous",
#     "promoted_content": null,
#     "tweet_volume": null,
#     "name": "#NoisyAndFamous"
#    }
#   ]
#  }
# ]

# %%
len(us_trends[0]['trends'])
for i in range(50):
    print(us_trends[0]['trends'][i]['url'])
    print(us_trends[0]['trends'][i]['query'])
# Out:
# http://twitter.com/search?q=%23HowToConfuseAMillennial
# %23HowToConfuseAMillennial
# http://twitter.com/search?q=%23SundayFunday
# %23SundayFunday
# http://twitter.com/search?q=%23FakeBirthdayFacts
# %23FakeBirthdayFacts
# http://twitter.com/search?q=%23WeAreReadyForSoloNiall
# %23WeAreReadyForSoloNiall
# http://twitter.com/search?q=%23HappyBirthdayBeyonce
# %23HappyBirthdayBeyonce
# http://twitter.com/search?q=Splyce
# Splyce
# http://twitter.com/search?q=%22Political+Correctness%22
# %22Political+Correctness%22
# http://twitter.com/search?q=Kimball
# Kimball
# http://twitter.com/search?q=%22Dr.+Collins%22
# %22Dr.+Collins%22
# http://twitter.com/search?q=Lackey
# Lackey
# http://twitter.com/search?q=Wozniacki
# Wozniacki
# http://twitter.com/search?q=Adrianza
# Adrianza
# http://twitter.com/search?q=%22Wade+Miley%22
# %22Wade+Miley%22
# http://twitter.com/search?q=%22Lauren+Holiday%22
# %22Lauren+Holiday%22
# http://twitter.com/search?q=%22Brian+Dozier%22
# %22Brian+Dozier%22
# http://twitter.com/search?q=%22Byron+Buxton%22
# %22Byron+Buxton%22
# http://twitter.com/search?q=%22Lucas+Pouille%22
# %22Lucas+Pouille%22
# http://twitter.com/search?q=%22Demaryius+Thomas%22
# %22Demaryius+Thomas%22
# http://twitter.com/search?q=%22Rahim+Moore%22
# %22Rahim+Moore%22
# http://twitter.com/search?q=%22Jumbo+Diaz%22
# %22Jumbo+Diaz%22
# http://twitter.com/search?q=%22Soledad+O%27Brien%22
# %22Soledad+O%27Brien%22
# http://twitter.com/search?q=%23DebbieDownerASongOrMovie
# %23DebbieDownerASongOrMovie
# http://twitter.com/search?q=%23obsessionstonight
# %23obsessionstonight
# http://twitter.com/search?q=%23IndyCarGP
# %23IndyCarGP
# http://twitter.com/search?q=%23ItsBestIfWe
# %23ItsBestIfWe
# http://twitter.com/search?q=%23PAXRUMBLE
# %23PAXRUMBLE
# http://twitter.com/search?q=%23WeLoveYouCalum
# %23WeLoveYouCalum
# http://twitter.com/search?q=%23LondonsBurning
# %23LondonsBurning
# http://twitter.com/search?q=%23ThingsToDoAtARedLight
# %23ThingsToDoAtARedLight
# http://twitter.com/search?q=%23BackToSchoolSongs
# %23BackToSchoolSongs
# http://twitter.com/search?q=%23WINGS
# %23WINGS
# http://twitter.com/search?q=%23SLFLIrvine
# %23SLFLIrvine
# http://twitter.com/search?q=%23DolansMakeMeSmile
# %23DolansMakeMeSmile
# http://twitter.com/search?q=%23SLOENG
# %23SLOENG
# http://twitter.com/search?q=%23NORGER
# %23NORGER
# http://twitter.com/search?q=%23OTHERtone
# %23OTHERtone
# http://twitter.com/search?q=%23NationalWildlifeDay
# %23NationalWildlifeDay
# http://twitter.com/search?q=%23SVKENG
# %23SVKENG
# http://twitter.com/search?q=%23AMJoy
# %23AMJoy
# http://twitter.com/search?q=%23NALCS
# %23NALCS
# http://twitter.com/search?q=%23radglowspoil
# %23radglowspoil
# http://twitter.com/search?q=%23EVOLutiontour
# %23EVOLutiontour
# http://twitter.com/search?q=%23Silverado250
# %23Silverado250
# http://twitter.com/search?q=%23NDvsTex
# %23NDvsTex
# http://twitter.com/search?q=%23shawolselcaday
# %23shawolselcaday
# http://twitter.com/search?q=%23MakeAMovieArrogant
# %23MakeAMovieArrogant
# http://twitter.com/search?q=%23TCMBacklot
# %23TCMBacklot
# http://twitter.com/search?q=%23MyFavChildhoodCartoon
# %23MyFavChildhoodCartoon
# http://twitter.com/search?q=%23BojanglesSo500
# %23BojanglesSo500
# http://twitter.com/search?q=%23NoisyAndFamous
# %23NoisyAndFamous

# %% [markdown]
# # Example 4. Computing the intersection of two sets of trends

# %%
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print(common_trends)
# Out:
# {'#WINGS', '#LondonsBurning', '#HowToConfuseAMillennial', '#WeLoveYouCalum', '#NORGER', '#SLOENG', 'Splyce', '#WeAreReadyForSoloNiall'}

# %%
world_trends[0]['trends'][0]['name']
# Out:
# '#WINGS'

# %%
world_trends_set
# Out:
# {'#ALGLES',
#  '#Arkadaşlarİyidir',
#  '#Barbecue',
#  '#BarışHemenŞimdi',
#  '#CeratiEterno',
#  '#ClaudiaLeitteNoTamanhoFamilia',
#  '#CuartoMilenio',
#  '#EdoDecides',
#  '#ElianaAoVivo',
#  '#EnSevdiğimYalan',
#  '#FelizDomingo',
#  '#GemeliersQTTF',
#  '#GildaPasionEterna',
#  '#HangiAşkAdilki',
#  '#HowToConfuseAMillennial',
#  '#KAZPOL',
#  '#LondonsBurning',
#  '#MALSCO',
#  '#Mesaza',
#  '#MessiEnPolemica',
#  '#MostMarvellousBook',
#  '#NORGER',
#  '#OT5MeansFamily',
#  '#PremierLundiDeCours',
#  '#Rockville4',
#  '#SLOENG',
#  '#Tatort',
#  '#TipsForYear7s',
#  '#UnFelpudoQueDiga',
#  '#WINGS',
#  '#WeAreReadyForSoloNiall',
#  '#WeLoveYouCalum',
#  '#ltwmv',
#  '#sorryvooralles',
#  '#sospascal',
#  '#vuelveElobjetivo',
#  '#zg16',
#  '#الاتحاد_57_بطوله_بالوثايق',
#  '#العيال_اصل_تويتر',
#  '#امتع_لاعب_بفريقك',
#  '#امنح_سعاده_ولو_برساله',
#  '#تيم_القمه_بيوزع',
#  '#جهود_المملكه_بالحج',
#  '#في_كل_عرس',
#  '#لن_تسقطي_الولايه_وسمعيني_صياحك',
#  '#لو_القتل_حلال_بتقتل_من',
#  '14binVatan HaininiTutukla',
#  'Camilo',
#  'Louis Tomlinson',
#  'Splyce'}

# %%
print(u'#\u0645\u0639\u0644\u0645\u064a\u0646_\u0627\u0644\u0627\u0631\u0628\u0639_\u0639\u0627\u0644\u0631\u0627\u062f\u064a\u0648_9090')
# Out:
# #معلمين_الاربع_عالراديو_9090

# %%
print(u'#\u0628\u0642\u0648\u0644_\u0643\u0641\u0627\u064a\u0647_\u0644')
# Out:
# #بقول_كفايه_ل

# %% [markdown]
# # Example 5. Collecting search results

# %%
#  Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.
import json

q = '#Kanye' 

count = 1000

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print("Length of statuses", len(statuses))
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses, indent=4))
# Out:
# Length of statuses 100
# Length of statuses 200
# Length of statuses 200
# [
#     {
#         "source": "<a href=\"http://www.projextra.ca\" rel=\"nofollow\">HipsterTweets</a>",
#         "geo": null,
#         "coordinates": null,
#         "created_at": "Sun Sep 04 20:00:11 +0000 2016",
#         "in_reply_to_status_id_str": null,
#         "entities": {
#             "user_mentions": [],
#             "urls": [],
#             "hashtags": [
#                 {
#                     "text": "hipster",
#                     "indices": [
#                         45,
#                         53
#                     ]
#                 },
#                 {
#                     "text": "kanye",
#                     "indices": [
#                         54,
#                         60
#                     ]
#                 }
#             ],
#             "symbols": []
#         },
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "truncated": false,
#         "in_reply_to_status_id": null,
#         "retweeted": false,
#         "id": 772524683040219136,
#         "place": null,
#         "retweet_count": 0,
#         "in_reply_to_user_id_str": null,
#         "favorite_count": 1,
#         "contributors": null,
#         "favorited": false,
#         "is_quote_status": false,
#         "lang": "en",
#         "id_str": "772524683040219136",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_user_id": null,
#         "text": "roof TV premiere tonight on E @ 7PM and 11PM #hipster #kanye",
#         "user": {
#             "profile_sidebar_border_color": "000000",
#             "verified": false,
#             "has_extended_profile": false,
#             "contributors_enabled": false,
#             "profile_sidebar_fill_color": "000000",
#             "id_str": "703385241000550401",
#             "notifications": false,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "location": "",
#             "is_translation_enabled": false,
#             "followers_count": 23,
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/703401706420379652/wpwf-Bn0_normal.jpg",
#             "time_zone": "Eastern Time (US & Canada)",
#             "profile_background_color": "000000",
#             "profile_text_color": "000000",
#             "id": 703385241000550401,
#             "profile_link_color": "ABB8C2",
#             "url": null,
#             "is_translator": false,
#             "geo_enabled": false,
#             "utc_offset": -14400,
#             "follow_request_sent": false,
#             "default_profile": false,
#             "description": "A mix of Ruby, Faker::Hipster and Kanye! Created by @xenilk",
#             "profile_use_background_image": false,
#             "friends_count": 1,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/703401706420379652/wpwf-Bn0_normal.jpg",
#             "name": "Hipster Kanye",
#             "lang": "en",
#             "created_at": "Sat Feb 27 01:04:44 +0000 2016",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "default_profile_image": false,
#             "listed_count": 10,
#             "following": false,
#             "statuses_count": 2373,
#             "favourites_count": 0,
#             "protected": false,
#             "screen_name": "KanyeHipster"
#         }
#     },
#     {
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "geo": null,
#         "coordinates": null,
#         "created_at": "Sun Sep 04 19:58:08 +0000 2016",
#         "extended_entities": {
#             "media": [
#                 {
#                     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/771064878152941568/pu/img/0F4mKg63-bqwJ9lL.jpg",
#                     "source_user_id_str": "47392492",
#                     "indices": [
#                         99,
#                         122
#                     ],
#                     "source_status_id": 771066094941528064,
#                     "id_str": "771064878152941568",
#                     "sizes": {
#                         "large": {
#                             "w": 640,
#                             "h": 640,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 600,
#                             "h": 600,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 340,
#                             "h": 340,
#                             "resize": "fit"
#                         }
#                     },
#                     "type": "video",
#                     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/771064878152941568/pu/img/0F4mKg63-bqwJ9lL.jpg",
#                     "additional_media_info": {
#                         "source_user": {
#                             "profile_sidebar_border_color": "000000",
#                             "verified": false,
#                             "has_extended_profile": true,
#                             "contributors_enabled": false,
#                             "profile_sidebar_fill_color": "1A161A",
#                             "id_str": "47392492",
#                             "notifications": false,
#                             "entities": {
#                                 "url": {
#                                     "urls": [
#                                         {
#                                             "expanded_url": "http://www.modelmayhem.com/chris05778",
#                                             "url": "https://t.co/rT5eWFquJv",
#                                             "indices": [
#                                                 0,
#                                                 23
#                                             ],
#                                             "display_url": "modelmayhem.com/chris05778"
#                                         }
#                                     ]
#                                 },
#                                 "description": {
#                                     "urls": []
#                                 }
#                             },
#                             "location": "N E W  Y O R K ",
#                             "is_translation_enabled": false,
#                             "followers_count": 1253,
#                             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000020437314/d8f57b3532fa0371ed482e7b65c878a6.jpeg",
#                             "profile_image_url_https": "https://pbs.twimg.com/profile_images/733541908773904385/VjFCsiOP_normal.jpg",
#                             "time_zone": "Central Time (US & Canada)",
#                             "profile_background_color": "ACDED6",
#                             "profile_text_color": "C72EC7",
#                             "id": 47392492,
#                             "profile_link_color": "9C9C93",
#                             "url": "https://t.co/rT5eWFquJv",
#                             "is_translator": false,
#                             "geo_enabled": true,
#                             "utc_offset": -18000,
#                             "follow_request_sent": false,
#                             "default_profile": false,
#                             "description": "SUBURBAN BOY| CHRIS COLE",
#                             "profile_use_background_image": true,
#                             "friends_count": 1053,
#                             "profile_image_url": "http://pbs.twimg.com/profile_images/733541908773904385/VjFCsiOP_normal.jpg",
#                             "profile_banner_url": "https://pbs.twimg.com/profile_banners/47392492/1472483842",
#                             "name": "K I N G B R E E ZY",
#                             "lang": "en",
#                             "created_at": "Mon Jun 15 17:40:28 +0000 2009",
#                             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000020437314/d8f57b3532fa0371ed482e7b65c878a6.jpeg",
#                             "profile_background_tile": true,
#                             "default_profile_image": false,
#                             "listed_count": 5,
#                             "following": false,
#                             "statuses_count": 16788,
#                             "favourites_count": 407,
#                             "protected": false,
#                             "screen_name": "Mak3M3AMod3L"
#                         },
#                         "monetizable": false
#                     },
#                     "source_status_id_str": "771066094941528064",
#                     "expanded_url": "https://twitter.com/Mak3M3AMod3L/status/771066094941528064/video/1",
#                     "video_info": {
#                         "duration_millis": 60033,
#                         "variants": [
#                             {
#                                 "content_type": "application/x-mpegURL",
#                                 "url": "https://video.twimg.com/ext_tw_video/771064878152941568/pu/pl/aOV82cx5CM0H6g57.m3u8"
#                             },
#                             {
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/771064878152941568/pu/vid/240x240/Qf-FF2Wpg9XqfXu3.mp4",
#                                 "bitrate": 320000
#                             },
#                             {
#                                 "content_type": "application/dash+xml",
#                                 "url": "https://video.twimg.com/ext_tw_video/771064878152941568/pu/pl/aOV82cx5CM0H6g57.mpd"
#                             },
#                             {
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/771064878152941568/pu/vid/480x480/BHIx0QgMpH8Asn_Y.mp4",
#                                 "bitrate": 832000
#                             }
#                         ],
#                         "aspect_ratio": [
#                             1,
#                             1
#                         ]
#                     },
#                     "source_user_id": 47392492,
#                     "id": 771064878152941568,
#                     "url": "https://t.co/H9KaK2c8aK",
#                     "display_url": "pic.twitter.com/H9KaK2c8aK"
#                 }
#             ]
#         },
#         "in_reply_to_status_id_str": null,
#         "entities": {
#             "media": [
#                 {
#                     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/771064878152941568/pu/img/0F4mKg63-bqwJ9lL.jpg",
#                     "source_user_id_str": "47392492",
#                     "indices": [
#                         99,
#                         122
#                     ],
#                     "source_status_id": 771066094941528064,
#                     "id_str": "771064878152941568",
#                     "sizes": {
#                         "large": {
#                             "w": 640,
#                             "h": 640,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 600,
#                             "h": 600,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 340,
#                             "h": 340,
#                             "resize": "fit"
#                         }
#                     },
#                     "type": "photo",
#                     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/771064878152941568/pu/img/0F4mKg63-bqwJ9lL.jpg",
#                     "source_status_id_str": "771066094941528064",
#                     "expanded_url": "https://twitter.com/Mak3M3AMod3L/status/771066094941528064/video/1",
#                     "source_user_id": 47392492,
#                     "id": 771064878152941568,
#                     "url": "https://t.co/H9KaK2c8aK",
#                     "display_url": "pic.twitter.com/H9KaK2c8aK"
#                 }
#             ],
#             "user_mentions": [
#                 {
#                     "id": 47392492,
#                     "id_str": "47392492",
#                     "indices": [
#                         3,
#                         16
#                     ],
#                     "screen_name": "Mak3M3AMod3L",
#                     "name": "K I N G B R E E ZY"
#                 }
#             ],
#             "urls": [],
#             "hashtags": [
#                 {
#                     "text": "TeyanaTaylor",
#                     "indices": [
#                         45,
#                         58
#                     ]
#                 },
#                 {
#                     "text": "Fade",
#                     "indices": [
#                         59,
#                         64
#                     ]
#                 },
#                 {
#                     "text": "KanyeWest",
#                     "indices": [
#                         65,
#                         75
#                     ]
#                 },
#                 {
#                     "text": "Yeezy",
#                     "indices": [
#                         76,
#                         82
#                     ]
#                 },
#                 {
#                     "text": "Kanye",
#                     "indices": [
#                         83,
#                         89
#                     ]
#                 },
#                 {
#                     "text": "TooSoon",
#                     "indices": [
#                         90,
#                         98
#                     ]
#                 }
#             ],
#             "symbols": []
#         },
#         "possibly_sensitive": false,
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "truncated": false,
#         "in_reply_to_status_id": null,
#         "retweeted": false,
#         "id": 772524163760328704,
#         "place": null,
#         "contributors": null,
#         "in_reply_to_user_id_str": null,
#         "favorite_count": 0,
#         "retweeted_status": {
#             "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#             "geo": null,
#             "coordinates": null,
#             "created_at": "Wed Aug 31 19:24:17 +0000 2016",
#             "extended_entities": {
#                 "media": [
#                     {
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/771064878152941568/pu/img/0F4mKg63-bqwJ9lL.jpg",
#                         "indices": [
#                             81,
#                             104
#                         ],
#                         "type": "video",
#                         "id_str": "771064878152941568",
#                         "sizes": {
#                             "large": {
#                                 "w": 640,
#                                 "h": 640,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 600,
#                                 "h": 600,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "small": {
#                                 "w": 340,
#                                 "h": 340,
#                                 "resize": "fit"
#                             }
#                         },
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/771064878152941568/pu/img/0F4mKg63-bqwJ9lL.jpg",
#                         "additional_media_info": {
#                             "monetizable": false
#                         },
#                         "expanded_url": "https://twitter.com/Mak3M3AMod3L/status/771066094941528064/video/1",
#                         "video_info": {
#                             "duration_millis": 60033,
#                             "variants": [
#                                 {
#                                     "content_type": "application/x-mpegURL",
#                                     "url": "https://video.twimg.com/ext_tw_video/771064878152941568/pu/pl/aOV82cx5CM0H6g57.m3u8"
#                                 },
#                                 {
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/771064878152941568/pu/vid/240x240/Qf-FF2Wpg9XqfXu3.mp4",
#                                     "bitrate": 320000
#                                 },
#                                 {
#                                     "content_type": "application/dash+xml",
#                                     "url": "https://video.twimg.com/ext_tw_video/771064878152941568/pu/pl/aOV82cx5CM0H6g57.mpd"
#                                 },
#                                 {
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/771064878152941568/pu/vid/480x480/BHIx0QgMpH8Asn_Y.mp4",
#                                     "bitrate": 832000
#                                 }
#                             ],
#                             "aspect_ratio": [
#                                 1,
#                                 1
#                             ]
#                         },
#                         "id": 771064878152941568,
#                         "url": "https://t.co/H9KaK2c8aK",
#                         "display_url": "pic.twitter.com/H9KaK2c8aK"
#                     }
#                 ]
#             },
#             "in_reply_to_status_id_str": null,
#             "entities": {
#                 "media": [
#                     {
#                         "id_str": "771064878152941568",
#                         "expanded_url": "https://twitter.com/Mak3M3AMod3L/status/771066094941528064/video/1",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/771064878152941568/pu/img/0F4mKg63-bqwJ9lL.jpg",
#                         "indices": [
#                             81,
#                             104
#                         ],
#                         "type": "photo",
#                         "id": 771064878152941568,
#                         "sizes": {
#                             "large": {
#                                 "w": 640,
#                                 "h": 640,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 600,
#                                 "h": 600,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "small": {
#                                 "w": 340,
#                                 "h": 340,
#                                 "resize": "fit"
#                             }
#                         },
#                         "url": "https://t.co/H9KaK2c8aK",
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/771064878152941568/pu/img/0F4mKg63-bqwJ9lL.jpg",
#                         "display_url": "pic.twitter.com/H9KaK2c8aK"
#                     }
#                 ],
#                 "user_mentions": [],
#                 "urls": [],
#                 "hashtags": [
#                     {
#                         "text": "TeyanaTaylor",
#                         "indices": [
#                             27,
#                             40
#                         ]
#                     },
#                     {
#                         "text": "Fade",
#                         "indices": [
#                             41,
#                             46
#                         ]
#                     },
#                     {
#                         "text": "KanyeWest",
#                         "indices": [
#                             47,
#                             57
#                         ]
#                     },
#                     {
#                         "text": "Yeezy",
#                         "indices": [
#                             58,
#                             64
#                         ]
#                     },
#                     {
#                         "text": "Kanye",
#                         "indices": [
#                             65,
#                             71
#                         ]
#                     },
#                     {
#                         "text": "TooSoon",
#                         "indices": [
#                             72,
#                             80
#                         ]
#                     }
#                 ],
#                 "symbols": []
#             },
#             "possibly_sensitive": false,
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "truncated": false,
#             "in_reply_to_status_id": null,
#             "retweeted": false,
#             "id": 771066094941528064,
#             "place": {
#                 "attributes": {},
#                 "contained_within": [],
#                 "country_code": "US",
#                 "country": "United States",
#                 "bounding_box": {
#                     "coordinates": [
#                         [
#                             [
#                                 -73.8516,
#                                 41.016743
#                             ],
#                             [
#                                 -73.771573,
#                                 41.016743
#                             ],
#                             [
#                                 -73.771573,
#                                 41.08284
#                             ],
#                             [
#                                 -73.8516,
#                                 41.08284
#                             ]
#                         ]
#                     ],
#                     "type": "Polygon"
#                 },
#                 "id": "01e766090e81ec56",
#                 "url": "https://api.twitter.com/1.1/geo/id/01e766090e81ec56.json",
#                 "place_type": "city",
#                 "name": "Greenburgh",
#                 "full_name": "Greenburgh, NY"
#             },
#             "retweet_count": 48,
#             "in_reply_to_user_id_str": null,
#             "favorite_count": 39,
#             "contributors": null,
#             "favorited": false,
#             "is_quote_status": false,
#             "lang": "en",
#             "id_str": "771066094941528064",
#             "in_reply_to_screen_name": null,
#             "in_reply_to_user_id": null,
#             "text": "Lmaooo I wasn't ready. \ud83d\ude2d\ud83d\ude2d\ud83d\ude2d #TeyanaTaylor #Fade #KanyeWest #Yeezy #Kanye #TooSoon https://t.co/H9KaK2c8aK",
#             "user": {
#                 "profile_sidebar_border_color": "000000",
#                 "verified": false,
#                 "has_extended_profile": true,
#                 "contributors_enabled": false,
#                 "profile_sidebar_fill_color": "1A161A",
#                 "id_str": "47392492",
#                 "notifications": false,
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "expanded_url": "http://www.modelmayhem.com/chris05778",
#                                 "url": "https://t.co/rT5eWFquJv",
#                                 "indices": [
#                                     0,
#                                     23
#                                 ],
#                                 "display_url": "modelmayhem.com/chris05778"
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "location": "N E W  Y O R K ",
#                 "is_translation_enabled": false,
#                 "followers_count": 1253,
#                 "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/378800000020437314/d8f57b3532fa0371ed482e7b65c878a6.jpeg",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/733541908773904385/VjFCsiOP_normal.jpg",
#                 "time_zone": "Central Time (US & Canada)",
#                 "profile_background_color": "ACDED6",
#                 "profile_text_color": "C72EC7",
#                 "id": 47392492,
#                 "profile_link_color": "9C9C93",
#                 "url": "https://t.co/rT5eWFquJv",
#                 "is_translator": false,
#                 "geo_enabled": true,
#                 "utc_offset": -18000,
#                 "follow_request_sent": false,
#                 "default_profile": false,
#                 "description": "SUBURBAN BOY| CHRIS COLE",
#                 "profile_use_background_image": true,
#                 "friends_count": 1053,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/733541908773904385/VjFCsiOP_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/47392492/1472483842",
#                 "name": "K I N G B R E E ZY",
#                 "lang": "en",
#                 "created_at": "Mon Jun 15 17:40:28 +0000 2009",
#                 "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/378800000020437314/d8f57b3532fa0371ed482e7b65c878a6.jpeg",
#                 "profile_background_tile": true,
#                 "default_profile_image": false,
#                 "listed_count": 5,
#                 "following": false,
#                 "statuses_count": 16788,
#                 "favourites_count": 407,
#                 "protected": false,
#                 "screen_name": "Mak3M3AMod3L"
#             }
#         },
#         "favorited": false,
#         "is_quote_status": false,
#         "retweet_count": 48,
#         "lang": "en",
#         "id_str": "772524163760328704",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_user_id": null,
#         "text": "RT @Mak3M3AMod3L: Lmaooo I wasn't ready. \ud83d\ude2d\ud83d\ude2d\ud83d\ude2d #TeyanaTaylor #Fade #KanyeWest #Yeezy #Kanye #TooSoon https://t.co/H9KaK2c8aK",
#         "user": {
#             "profile_sidebar_border_color": "C0DEED",
#             "verified": false,
#             "has_extended_profile": true,
#             "contributors_enabled": false,
#             "profile_sidebar_fill_color": "DDEEF6",
#             "id_str": "1514239404",
#             "notifications": false,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "location": "Reading, England",
#             "is_translation_enabled": false,
#             "followers_count": 149,
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000830414520/901afa3b26887e51f124f96142b02468_normal.jpeg",
#             "time_zone": "Hawaii",
#             "profile_background_color": "C0DEED",
#             "profile_text_color": "333333",
#             "id": 1514239404,
#             "profile_link_color": "0084B4",
#             "url": null,
#             "is_translator": false,
#             "geo_enabled": true,
#             "utc_offset": -36000,
#             "follow_request_sent": false,
#             "default_profile": true,
#             "description": "Add my snapchat: beckiiv_xo",
#             "profile_use_background_image": true,
#             "friends_count": 151,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/378800000830414520/901afa3b26887e51f124f96142b02468_normal.jpeg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/1514239404/1451855726",
#             "name": "B\u2696",
#             "lang": "en",
#             "created_at": "Thu Jun 13 19:33:24 +0000 2013",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "default_profile_image": false,
#             "listed_count": 0,
#             "following": false,
#             "statuses_count": 760,
#             "favourites_count": 166,
#             "protected": false,
#             "screen_name": "beckiivaughan"
#         }
#     },
#     {
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "geo": null,
#         "coordinates": null,
#         "created_at": "Sun Sep 04 19:55:33 +0000 2016",
#         "extended_entities": {
#             "media": [
#                 {
#                     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/772141814539165696/pu/img/A3MsH2VEVHfbMbJs.jpg",
#                     "source_user_id_str": "741981557913575432",
#                     "indices": [
#                         79,
#                         102
#                     ],
#                     "source_status_id": 772144138099822592,
#                     "id_str": "772141814539165696",
#                     "sizes": {
#                         "large": {
#                             "w": 1024,
#                             "h": 576,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 600,
#                             "h": 338,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 340,
#                             "h": 191,
#                             "resize": "fit"
#                         }
#                     },
#                     "type": "video",
#                     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/772141814539165696/pu/img/A3MsH2VEVHfbMbJs.jpg",
#                     "additional_media_info": {
#                         "source_user": {
#                             "profile_sidebar_border_color": "000000",
#                             "verified": false,
#                             "has_extended_profile": true,
#                             "contributors_enabled": false,
#                             "profile_sidebar_fill_color": "000000",
#                             "id_str": "741981557913575432",
#                             "notifications": false,
#                             "entities": {
#                                 "url": {
#                                     "urls": [
#                                         {
#                                             "expanded_url": "http://tidal.com/us/store/artist/8002758",
#                                             "url": "https://t.co/nuBSazlG5a",
#                                             "indices": [
#                                                 0,
#                                                 23
#                                             ],
#                                             "display_url": "tidal.com/us/store/artis\u2026"
#                                         }
#                                     ]
#                                 },
#                                 "description": {
#                                     "urls": []
#                                 }
#                             },
#                             "location": "Timbuktu",
#                             "is_translation_enabled": false,
#                             "followers_count": 202,
#                             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#                             "profile_image_url_https": "https://pbs.twimg.com/profile_images/758036130734284800/sOcceNFX_normal.jpg",
#                             "time_zone": null,
#                             "profile_background_color": "000000",
#                             "profile_text_color": "000000",
#                             "id": 741981557913575432,
#                             "profile_link_color": "981CEB",
#                             "url": "https://t.co/nuBSazlG5a",
#                             "is_translator": false,
#                             "geo_enabled": false,
#                             "utc_offset": null,
#                             "follow_request_sent": false,
#                             "default_profile": false,
#                             "description": "ROK || ZION Contact: rokbooking@gmail.com | featuresrok@gmail.com Signed",
#                             "profile_use_background_image": false,
#                             "friends_count": 200,
#                             "profile_image_url": "http://pbs.twimg.com/profile_images/758036130734284800/sOcceNFX_normal.jpg",
#                             "profile_banner_url": "https://pbs.twimg.com/profile_banners/741981557913575432/1469564833",
#                             "name": "DEDDY\u2122",
#                             "lang": "en",
#                             "created_at": "Sun Jun 12 13:12:43 +0000 2016",
#                             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#                             "profile_background_tile": false,
#                             "default_profile_image": false,
#                             "listed_count": 3,
#                             "following": false,
#                             "statuses_count": 1020,
#                             "favourites_count": 939,
#                             "protected": false,
#                             "screen_name": "Ahmad_Jammrok"
#                         },
#                         "monetizable": false
#                     },
#                     "source_status_id_str": "772144138099822592",
#                     "expanded_url": "https://twitter.com/Ahmad_Jammrok/status/772144138099822592/video/1",
#                     "video_info": {
#                         "duration_millis": 140000,
#                         "variants": [
#                             {
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/772141814539165696/pu/vid/320x180/WrvhMPkEpkQZgfRX.mp4",
#                                 "bitrate": 320000
#                             },
#                             {
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/772141814539165696/pu/vid/640x360/vT4grwg_pwIw0Joh.mp4",
#                                 "bitrate": 832000
#                             },
#                             {
#                                 "content_type": "application/x-mpegURL",
#                                 "url": "https://video.twimg.com/ext_tw_video/772141814539165696/pu/pl/r3J3hW5lubcvW1eD.m3u8"
#                             },
#                             {
#                                 "content_type": "video/mp4",
#                                 "url": "https://video.twimg.com/ext_tw_video/772141814539165696/pu/vid/1280x720/ocyRA7WTWQLx0HbS.mp4",
#                                 "bitrate": 2176000
#                             },
#                             {
#                                 "content_type": "application/dash+xml",
#                                 "url": "https://video.twimg.com/ext_tw_video/772141814539165696/pu/pl/r3J3hW5lubcvW1eD.mpd"
#                             }
#                         ],
#                         "aspect_ratio": [
#                             16,
#                             9
#                         ]
#                     },
#                     "source_user_id": 741981557913575432,
#                     "id": 772141814539165696,
#                     "url": "https://t.co/cqqETQHzIP",
#                     "display_url": "pic.twitter.com/cqqETQHzIP"
#                 }
#             ]
#         },
#         "in_reply_to_status_id_str": null,
#         "entities": {
#             "media": [
#                 {
#                     "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/772141814539165696/pu/img/A3MsH2VEVHfbMbJs.jpg",
#                     "source_user_id_str": "741981557913575432",
#                     "indices": [
#                         79,
#                         102
#                     ],
#                     "source_status_id": 772144138099822592,
#                     "id_str": "772141814539165696",
#                     "sizes": {
#                         "large": {
#                             "w": 1024,
#                             "h": 576,
#                             "resize": "fit"
#                         },
#                         "medium": {
#                             "w": 600,
#                             "h": 338,
#                             "resize": "fit"
#                         },
#                         "thumb": {
#                             "w": 150,
#                             "h": 150,
#                             "resize": "crop"
#                         },
#                         "small": {
#                             "w": 340,
#                             "h": 191,
#                             "resize": "fit"
#                         }
#                     },
#                     "type": "photo",
#                     "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/772141814539165696/pu/img/A3MsH2VEVHfbMbJs.jpg",
#                     "source_status_id_str": "772144138099822592",
#                     "expanded_url": "https://twitter.com/Ahmad_Jammrok/status/772144138099822592/video/1",
#                     "source_user_id": 741981557913575432,
#                     "id": 772141814539165696,
#                     "url": "https://t.co/cqqETQHzIP",
#                     "display_url": "pic.twitter.com/cqqETQHzIP"
#                 }
#             ],
#             "user_mentions": [
#                 {
#                     "id": 741981557913575432,
#                     "id_str": "741981557913575432",
#                     "indices": [
#                         3,
#                         17
#                     ],
#                     "screen_name": "Ahmad_Jammrok",
#                     "name": "DEDDY\u2122"
#                 }
#             ],
#             "urls": [],
#             "hashtags": [
#                 {
#                     "text": "Fade",
#                     "indices": [
#                         39,
#                         44
#                     ]
#                 },
#                 {
#                     "text": "Kanye",
#                     "indices": [
#                         45,
#                         51
#                     ]
#                 },
#                 {
#                     "text": "Rihanna",
#                     "indices": [
#                         52,
#                         60
#                     ]
#                 },
#                 {
#                     "text": "VMA",
#                     "indices": [
#                         67,
#                         71
#                     ]
#                 },
#                 {
#                     "text": "Jaden",
#                     "indices": [
#                         72,
#                         78
#                     ]
#                 }
#             ],
#             "symbols": []
#         },
#         "possibly_sensitive": false,
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "truncated": false,
#         "in_reply_to_status_id": null,
#         "retweeted": false,
#         "id": 772523513810911232,
#         "place": null,
#         "contributors": null,
#         "in_reply_to_user_id_str": null,
#         "favorite_count": 0,
#         "retweeted_status": {
#             "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#             "geo": null,
#             "coordinates": null,
#             "created_at": "Sat Sep 03 18:48:02 +0000 2016",
#             "extended_entities": {
#                 "media": [
#                     {
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/772141814539165696/pu/img/A3MsH2VEVHfbMbJs.jpg",
#                         "indices": [
#                             60,
#                             83
#                         ],
#                         "type": "video",
#                         "id_str": "772141814539165696",
#                         "sizes": {
#                             "large": {
#                                 "w": 1024,
#                                 "h": 576,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 600,
#                                 "h": 338,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "small": {
#                                 "w": 340,
#                                 "h": 191,
#                                 "resize": "fit"
#                             }
#                         },
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/772141814539165696/pu/img/A3MsH2VEVHfbMbJs.jpg",
#                         "additional_media_info": {
#                             "monetizable": false
#                         },
#                         "expanded_url": "https://twitter.com/Ahmad_Jammrok/status/772144138099822592/video/1",
#                         "video_info": {
#                             "duration_millis": 140000,
#                             "variants": [
#                                 {
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/772141814539165696/pu/vid/320x180/WrvhMPkEpkQZgfRX.mp4",
#                                     "bitrate": 320000
#                                 },
#                                 {
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/772141814539165696/pu/vid/640x360/vT4grwg_pwIw0Joh.mp4",
#                                     "bitrate": 832000
#                                 },
#                                 {
#                                     "content_type": "application/x-mpegURL",
#                                     "url": "https://video.twimg.com/ext_tw_video/772141814539165696/pu/pl/r3J3hW5lubcvW1eD.m3u8"
#                                 },
#                                 {
#                                     "content_type": "video/mp4",
#                                     "url": "https://video.twimg.com/ext_tw_video/772141814539165696/pu/vid/1280x720/ocyRA7WTWQLx0HbS.mp4",
#                                     "bitrate": 2176000
#                                 },
#                                 {
#                                     "content_type": "application/dash+xml",
#                                     "url": "https://video.twimg.com/ext_tw_video/772141814539165696/pu/pl/r3J3hW5lubcvW1eD.mpd"
#                                 }
#                             ],
#                             "aspect_ratio": [
#                                 16,
#                                 9
#                             ]
#                         },
#                         "id": 772141814539165696,
#                         "url": "https://t.co/cqqETQHzIP",
#                         "display_url": "pic.twitter.com/cqqETQHzIP"
#                     }
#                 ]
#             },
#             "in_reply_to_status_id_str": null,
#             "entities": {
#                 "media": [
#                     {
#                         "id_str": "772141814539165696",
#                         "expanded_url": "https://twitter.com/Ahmad_Jammrok/status/772144138099822592/video/1",
#                         "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/772141814539165696/pu/img/A3MsH2VEVHfbMbJs.jpg",
#                         "indices": [
#                             60,
#                             83
#                         ],
#                         "type": "photo",
#                         "id": 772141814539165696,
#                         "sizes": {
#                             "large": {
#                                 "w": 1024,
#                                 "h": 576,
#                                 "resize": "fit"
#                             },
#                             "medium": {
#                                 "w": 600,
#                                 "h": 338,
#                                 "resize": "fit"
#                             },
#                             "thumb": {
#                                 "w": 150,
#                                 "h": 150,
#                                 "resize": "crop"
#                             },
#                             "small": {
#                                 "w": 340,
#                                 "h": 191,
#                                 "resize": "fit"
#                             }
#                         },
#                         "url": "https://t.co/cqqETQHzIP",
#                         "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/772141814539165696/pu/img/A3MsH2VEVHfbMbJs.jpg",
#                         "display_url": "pic.twitter.com/cqqETQHzIP"
#                     }
#                 ],
#                 "user_mentions": [],
#                 "urls": [],
#                 "hashtags": [
#                     {
#                         "text": "Fade",
#                         "indices": [
#                             20,
#                             25
#                         ]
#                     },
#                     {
#                         "text": "Kanye",
#                         "indices": [
#                             26,
#                             32
#                         ]
#                     },
#                     {
#                         "text": "Rihanna",
#                         "indices": [
#                             33,
#                             41
#                         ]
#                     },
#                     {
#                         "text": "VMA",
#                         "indices": [
#                             48,
#                             52
#                         ]
#                     },
#                     {
#                         "text": "Jaden",
#                         "indices": [
#                             53,
#                             59
#                         ]
#                     }
#                 ],
#                 "symbols": []
#             },
#             "possibly_sensitive": false,
#             "metadata": {
#                 "iso_language_code": "en",
#                 "result_type": "recent"
#             },
#             "truncated": false,
#             "in_reply_to_status_id": null,
#             "retweeted": false,
#             "id": 772144138099822592,
#             "place": null,
#             "retweet_count": 3,
#             "in_reply_to_user_id_str": null,
# ...
#                                 "indices": [
#                                     0,
#                                     22
#                                 ],
#                                 "display_url": "BlackBoySocials.com"
#                             }
#                         ]
#                     },
#                     "description": {
#                         "urls": []
#                     }
#                 },
#                 "location": "",
#                 "is_translation_enabled": false,
#                 "followers_count": 177,
#                 "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#                 "profile_image_url_https": "https://pbs.twimg.com/profile_images/592386982354915328/bgGKNK0e_normal.jpg",
#                 "time_zone": "Eastern Time (US & Canada)",
#                 "profile_background_color": "131516",
#                 "profile_text_color": "333333",
#                 "id": 730833452,
#                 "profile_link_color": "009999",
#                 "url": "http://t.co/4VRmj6UI9X",
#                 "is_translator": false,
#                 "geo_enabled": false,
#                 "utc_offset": -14400,
#                 "follow_request_sent": false,
#                 "default_profile": false,
#                 "description": "#NYC #LosAngeles #Toronto #Detroit #Miami #Atlanta #Chicago        #BBSGirls Submit pics to blackboysocials@gmail.com",
#                 "profile_use_background_image": true,
#                 "friends_count": 632,
#                 "profile_image_url": "http://pbs.twimg.com/profile_images/592386982354915328/bgGKNK0e_normal.jpg",
#                 "profile_banner_url": "https://pbs.twimg.com/profile_banners/730833452/1406744047",
#                 "name": "BlackBoySocials",
#                 "lang": "en",
#                 "created_at": "Wed Aug 01 14:57:28 +0000 2012",
#                 "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#                 "profile_background_tile": true,
#                 "default_profile_image": false,
#                 "listed_count": 1,
#                 "following": false,
#                 "statuses_count": 603,
#                 "favourites_count": 532,
#                 "protected": false,
#                 "screen_name": "BlackBoySocials"
#             }
#         },
#         "contributors": null,
#         "favorited": false,
#         "is_quote_status": false,
#         "lang": "en",
#         "id_str": "772221469506109441",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_user_id": null,
#         "text": "RT @BlackBoySocials: Here is the entire Fade video. Enjoy accordingly. #Kanye #TeyanaTaylor  https://t.co/2zLkg3mDGD \u2026",
#         "user": {
#             "profile_sidebar_border_color": "EEEEEE",
#             "verified": false,
#             "has_extended_profile": false,
#             "contributors_enabled": false,
#             "profile_sidebar_fill_color": "EFEFEF",
#             "id_str": "375703368",
#             "notifications": false,
#             "entities": {
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "location": "",
#             "is_translation_enabled": false,
#             "followers_count": 134,
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/496631449471430656/rOccNiDz_normal.jpeg",
#             "time_zone": "Central Time (US & Canada)",
#             "profile_background_color": "131516",
#             "profile_text_color": "333333",
#             "id": 375703368,
#             "profile_link_color": "009999",
#             "url": null,
#             "is_translator": false,
#             "geo_enabled": true,
#             "utc_offset": -18000,
#             "follow_request_sent": false,
#             "default_profile": false,
#             "description": "",
#             "profile_use_background_image": true,
#             "friends_count": 199,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/496631449471430656/rOccNiDz_normal.jpeg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/375703368/1407027721",
#             "name": "King V",
#             "lang": "en",
#             "created_at": "Sun Sep 18 15:59:31 +0000 2011",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#             "profile_background_tile": true,
#             "default_profile_image": false,
#             "listed_count": 3,
#             "following": false,
#             "statuses_count": 7242,
#             "favourites_count": 315,
#             "protected": false,
#             "screen_name": "iSimply_Vince"
#         }
#     },
#     {
#         "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#         "geo": null,
#         "coordinates": null,
#         "created_at": "Sat Sep 03 23:52:39 +0000 2016",
#         "in_reply_to_status_id_str": null,
#         "entities": {
#             "user_mentions": [],
#             "urls": [
#                 {
#                     "expanded_url": "http://www.ebay.com/itm/MASSIVE-LOT-Of-49-Marvel-Comics-Hip-Hop-Variant-Covers-RARE-HTF-BONUS-/152227863211?roken=cUgayN&soutkn=BpSg6S",
#                     "url": "https://t.co/GL3ggwmb7s",
#                     "indices": [
#                         106,
#                         129
#                     ],
#                     "display_url": "ebay.com/itm/MASSIVE-LO\u2026"
#                 }
#             ],
#             "hashtags": [
#                 {
#                     "text": "MarvelComics",
#                     "indices": [
#                         15,
#                         28
#                     ]
#                 },
#                 {
#                     "text": "HipHopVariant",
#                     "indices": [
#                         29,
#                         43
#                     ]
#                 },
#                 {
#                     "text": "KanyeWest",
#                     "indices": [
#                         61,
#                         71
#                     ]
#                 },
#                 {
#                     "text": "NickiMinaj",
#                     "indices": [
#                         72,
#                         83
#                     ]
#                 },
#                 {
#                     "text": "Drake",
#                     "indices": [
#                         84,
#                         90
#                     ]
#                 },
#                 {
#                     "text": "Kanye",
#                     "indices": [
#                         91,
#                         97
#                     ]
#                 },
#                 {
#                     "text": "HipHop",
#                     "indices": [
#                         98,
#                         105
#                     ]
#                 }
#             ],
#             "symbols": []
#         },
#         "possibly_sensitive": false,
#         "metadata": {
#             "iso_language_code": "en",
#             "result_type": "recent"
#         },
#         "truncated": false,
#         "in_reply_to_status_id": null,
#         "retweeted": false,
#         "id": 772220797255548928,
#         "place": null,
#         "retweet_count": 0,
#         "in_reply_to_user_id_str": null,
#         "favorite_count": 1,
#         "contributors": null,
#         "favorited": false,
#         "is_quote_status": false,
#         "lang": "en",
#         "id_str": "772220797255548928",
#         "in_reply_to_screen_name": null,
#         "in_reply_to_user_id": null,
#         "text": "HUGE Lot Of 49 #MarvelComics #HipHopVariant Covers! + BONUS! #KanyeWest #NickiMinaj #Drake #Kanye #HipHop https://t.co/GL3ggwmb7s",
#         "user": {
#             "profile_sidebar_border_color": "000000",
#             "verified": false,
#             "has_extended_profile": false,
#             "contributors_enabled": false,
#             "profile_sidebar_fill_color": "000000",
#             "id_str": "4019950995",
#             "notifications": false,
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "expanded_url": "http://stores.ebay.com/roguegeek7",
#                             "url": "https://t.co/dhisdasqA8",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "display_url": "stores.ebay.com/roguegeek7"
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": []
#                 }
#             },
#             "location": "",
#             "is_translation_enabled": false,
#             "followers_count": 26,
#             "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/657332111523868672/iYqunqtW_normal.jpg",
#             "time_zone": "Eastern Time (US & Canada)",
#             "profile_background_color": "000000",
#             "profile_text_color": "000000",
#             "id": 4019950995,
#             "profile_link_color": "981CEB",
#             "url": "https://t.co/dhisdasqA8",
#             "is_translator": false,
#             "geo_enabled": true,
#             "utc_offset": -14400,
#             "follow_request_sent": false,
#             "default_profile": false,
#             "description": "NO spam here. I'm trying to save my store, so I use this to promote my eBay auctions. Tweets updated daily. Appreciate ANY RTs.",
#             "profile_use_background_image": false,
#             "friends_count": 62,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/657332111523868672/iYqunqtW_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/4019950995/1468915301",
#             "name": "Rogue Geek!",
#             "lang": "en",
#             "created_at": "Thu Oct 22 22:42:40 +0000 2015",
#             "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#             "profile_background_tile": false,
#             "default_profile_image": false,
#             "listed_count": 25,
#             "following": false,
#             "statuses_count": 233,
#             "favourites_count": 0,
#             "protected": false,
#             "screen_name": "comicsrogue7"
#         }
#     },
#     {
#         "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#         "geo": null,
#         "coordinates": null,
#         "created_at": "Sat Sep 03 23:50:00 +0000 2016",
#         "in_reply_to_status_id_str": "772219347775389697",
#         "entities": {
#             "user_mentions": [
#                 {
#                     "id": 1215024235,
#                     "id_str": "1215024235",
#                     "indices": [
#                         0,
#                         9
#                     ],
#                     "screen_name": "Big7ShoT",
#                     "name": "\u0639\u0628\u062f\u0627\u0644\u0631\u062d\u0645\u0646\u26a1\ufe0fBolt"
#                 }
#             ],
#             "urls": [],
#             "hashtags": [
#                 {
#                     "text": "HighSelfesteem",
#                     "indices": [
#                         78,
#                         93
#                     ]
#                 },
#                 {
#                     "text": "Kanye",
#                     "indices": [
#                         94,
#                         100
#                     ]
#                 },
#                 {
#                     "text": "EllectOwl",
#                     "indices": [
#                         101,
#                         111
#                     ]
#                 }
#             ],
#             "symbols": []
#         },
#         "metadata": {
#             "iso_language_code": "ar",
#             "result_type": "recent"
#         },
#         "truncated": false,
#         "in_reply_to_status_id": 772219347775389697,
#         "retweeted": false,
#         "id": 772220128775835648,
#         "place": null,
#         "retweet_count": 0,
#         "in_reply_to_user_id_str": "1215024235",
#         "favorite_count": 0,
#         "contributors": null,
#         "favorited": false,
#         "is_quote_status": false,
#         "lang": "ar",
#         "id_str": "772220128775835648",
#         "in_reply_to_screen_name": "Big7ShoT",
#         "in_reply_to_user_id": 1215024235,
#         "text": "@Big7ShoT \u0644\u0627 \u0627\u0646\u0627 \u062f\u0627\u064a\u0631\u0643\u062a\u060c \u0627\u0636\u062d\u0643 \u0639\u0644\u0649 \u062a\u0648\u064a\u062a\u0627\u062a\u064a \u0645\u0646 \u0646\u0641\u0633 \u0627\u0644\u0627\u0643\u0627\u0648\u0646\u062a\u060c \u0645\u0627 \u0627\u0646\u0637\u0631 \u0627\u062d\u062f \u064a\u062a\u0643\u0631\u0645. #HighSelfesteem #Kanye #EllectOwl",
#         "user": {
#             "profile_sidebar_border_color": "FFFFFF",
#             "verified": false,
#             "has_extended_profile": false,
#             "contributors_enabled": false,
#             "profile_sidebar_fill_color": "DDEEF6",
#             "id_str": "2716389392",
#             "notifications": false,
#             "entities": {
#                 "url": {
#                     "urls": [
#                         {
#                             "expanded_url": "https://twitter.com/3gerardpique/status/607312534291513344",
#                             "url": "https://t.co/ENBhzYwjgv",
#                             "indices": [
#                                 0,
#                                 23
#                             ],
#                             "display_url": "twitter.com/3gerardpique/s\u2026"
#                         }
#                     ]
#                 },
#                 "description": {
#                     "urls": [
#                         {
#                             "expanded_url": "http://curiouscat.me/Baecelona9",
#                             "url": "https://t.co/d70KTCo2Zi",
#                             "indices": [
#                                 16,
#                                 39
#                             ],
#                             "display_url": "curiouscat.me/Baecelona9"
#                         }
#                     ]
#                 }
#             },
#             "location": "Normal, IL",
#             "is_translation_enabled": false,
#             "followers_count": 398,
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/497641998749147136/Ix77csWW.jpeg",
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/675802349693177857/yVaecpBp_normal.jpg",
#             "time_zone": "Madrid",
#             "profile_background_color": "B8CFDB",
#             "profile_text_color": "333333",
#             "id": 2716389392,
#             "profile_link_color": "3E5D7D",
#             "url": "https://t.co/ENBhzYwjgv",
#             "is_translator": false,
#             "geo_enabled": true,
#             "utc_offset": 7200,
#             "follow_request_sent": false,
#             "default_profile": false,
#             "description": "I'm not an owl. https://t.co/d70KTCo2Zi",
#             "profile_use_background_image": true,
#             "friends_count": 374,
#             "profile_image_url": "http://pbs.twimg.com/profile_images/675802349693177857/yVaecpBp_normal.jpg",
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/2716389392/1462385359",
#             "name": "O W L \ud83d\udc36",
#             "lang": "en",
#             "created_at": "Fri Aug 08 06:58:14 +0000 2014",
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/497641998749147136/Ix77csWW.jpeg",
#             "profile_background_tile": true,
#             "default_profile_image": false,
#             "listed_count": 3,
#             "following": false,
#             "statuses_count": 35740,
#             "favourites_count": 12616,
#             "protected": false,
#             "screen_name": "Baecelona9"
#         }
#     }
# ]

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 6. Extracting text, screen names, and hashtags from tweets

# %%
import time


status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1))
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "roof TV premiere tonight on E @ 7PM and 11PM #hipster #kanye",
#  "RT @Mak3M3AMod3L: Lmaooo I wasn't ready. \ud83d\ude2d\ud83d\ude2d\ud83d\ude2d #TeyanaTaylor #Fade #KanyeWest #Yeezy #Kanye #TooSoon https://t.co/H9KaK2c8aK",
#  "RT @Ahmad_Jammrok: G. WHOS RESPONSIBLE #Fade #Kanye #Rihanna #2016 #VMA #Jaden https://t.co/cqqETQHzIP",
#  "RT @PatronGrp: Stellar instrumental from German producer @Henrik_3000 https://t.co/iPlXeE18sn #hiphop #kanye #instrumental",
#  "\ud83c\udfbc I just fade away, deep inside deep deep down inside \ud83c\udfbc #MJ #werewolf #catface #kanye https://t.co/dQKE6RyK4G"
# ]
# [
#  "Mak3M3AMod3L",
#  "Ahmad_Jammrok",
#  "PatronGrp",
#  "Henrik_3000",
#  "ShgAntar"
# ]
# [
#  "hipster",
#  "kanye",
#  "TeyanaTaylor",
#  "Fade",
#  "KanyeWest"
# ]
# [
#  "roof",
#  "TV",
#  "premiere",
#  "tonight",
#  "on"
# ]

# %% [markdown]
# # Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
# Out:
# [('#Kanye', 93), ('#kanye', 86), ('the', 49), ('RT', 46), ('I', 30), ('to', 25), ('you', 24), ('of', 23), ('for', 22), ('and', 22)]
# [('kanyewest', 10), ('tdgarden', 4), ('C_Red17', 4), ('YouTube', 3), ('Ahmad_Jammrok', 3), ('KimKardashian', 3), ('BlackBoySocials', 3), ('djkhaled', 3), ('gabeamo', 2), ('elizabethhdre', 2)]
# [('Kanye', 107), ('kanye', 90), ('yeezy', 17), ('kanyewest', 17), ('SaintPabloTour', 16), ('hipster', 14), ('KanyeWest', 10), ('yeezus', 7), ('pablo', 7), ('Yeezy', 7)]

# %% [markdown]
# # Example 8. Using prettytable to display tuples in a nice tabular format

# %%
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print(pt)
# Out:
# +--------+-------+
# | Word   | Count |
# +--------+-------+
# | #Kanye |    93 |
# | #kanye |    86 |
# | the    |    49 |
# | RT     |    46 |
# | I      |    30 |
# | to     |    25 |
# | you    |    24 |
# | of     |    23 |
# | for    |    22 |
# | and    |    22 |
# +--------+-------+
# +-----------------+-------+
# | Screen Name     | Count |
# +-----------------+-------+
# | kanyewest       |    10 |
# | tdgarden        |     4 |
# | C_Red17         |     4 |
# | YouTube         |     3 |
# | Ahmad_Jammrok   |     3 |
# | KimKardashian   |     3 |
# | BlackBoySocials |     3 |
# | djkhaled        |     3 |
# | gabeamo         |     2 |
# | elizabethhdre   |     2 |
# +-----------------+-------+
# +----------------+-------+
# | Hashtag        | Count |
# +----------------+-------+
# | Kanye          |   107 |
# | kanye          |    90 |
# | yeezy          |    17 |
# | kanyewest      |    17 |
# | SaintPabloTour |    16 |
# | hipster        |    14 |
# | KanyeWest      |    10 |
# | yeezus         |     7 |
# | pablo          |     7 |
# | Yeezy          |     7 |
# +----------------+-------+

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 9. Calculating lexical diversity for tweets

# %%
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print(lexical_diversity(words))
print(lexical_diversity(screen_names))
print(lexical_diversity(hashtags))
print(average_words(status_texts))
# Out:
# 0.5048435171385991
# 0.6173913043478261
# 0.38366718027734975
# 13.42

# %% [markdown]
# ## Back to slides

# %% [markdown]
# # Example 10. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text']) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# Slice off the first 5 from the sorted results and display each item in the tuple

pt = PrettyTable(field_names=['Count', 'Screen Name', 'Text'])
[ pt.add_row(row) for row in sorted(retweets, reverse=True)[:5] ]
pt.max_width['Text'] = 50
pt.align= 'l'
print(pt)
# Out:
# +-------+-----------------+----------------------------------------------------+
# | Count | Screen Name     | Text                                               |
# +-------+-----------------+----------------------------------------------------+
# | 985   | elizabethhdre   | RT @elizabethhdre: Another jacket, another         |
# |       |                 | painting. #yeezus #kanye 🎓 https://t.co/RmaCD85KdX |
# | 985   | elizabethhdre   | RT @elizabethhdre: Another jacket, another         |
# |       |                 | painting. #yeezus #kanye 🎓 https://t.co/RmaCD85KdX |
# | 554   | SarantosMelogia | RT @SarantosMelogia: FUNNY!!                       |
# |       |                 |                                                    |
# |       |                 | https://t.co/LQYsOIiqXn                            |
# |       |                 |                                                    |
# |       |                 | #jamescorden                                       |
# |       |                 | #kanye                                             |
# |       |                 | #fade                                              |
# |       |                 | #musicvideo                                        |
# |       |                 | #musicvideoalert                                   |
# |       |                 | #mtv                                               |
# |       |                 | #funny                                             |
# |       |                 | #videooftheday ht…                                 |
# | 360   | BlackBoySocials | RT @BlackBoySocials: Here is the entire Fade       |
# |       |                 | video. Enjoy accordingly. #Kanye #TeyanaTaylor     |
# |       |                 | https://t.co/2zLkg3mDGD …                          |
# | 360   | BlackBoySocials | RT @BlackBoySocials: Here is the entire Fade       |
# |       |                 | video. Enjoy accordingly. #Kanye #TeyanaTaylor     |
# |       |                 | https://t.co/2zLkg3mDGD …                          |
# +-------+-----------------+----------------------------------------------------+

# %% [markdown]
# ## Back to slides

# %% [markdown]
# #  Example 11. Plotting frequencies of words

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  


word_counts = sorted(Counter(words).values(), reverse=True)



plt.loglog(word_counts)
plt.ylabel("Freq")
plt.xlabel("Word Rank")

# %% [markdown]
# # Example 12. Generating a histogram of retweet counts

# %%
# Using underscores while unpacking values in
# a tuple is idiomatic for discarding them

counts = [count for count, _, _ in retweets]

plt.hist(counts)
plt.title("Retweets")
plt.xlabel('Bins (number of times retweeted)')
plt.ylabel('Number of tweets in bin')

print(counts)
# Out:
# [48, 3, 1, 1, 985, 123, 2, 2, 123, 2, 123, 2, 123, 2, 2, 2, 1, 1, 360, 1, 554, 2, 1, 3, 1, 1, 118, 3, 118, 1, 1, 2, 2, 1, 1, 3, 360, 204, 204, 3, 985, 2, 1, 1, 360]
